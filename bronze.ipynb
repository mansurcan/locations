# %% [markdown]
# #### Initialize the Spark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Bronze") \
    .config("spark.jars.packages", "com.crealytics:spark-excel_2.12:0.13.5") \
    .getOrCreate()

# %% [markdown]
# #### Schemas for files

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType

# Define the schema for the Locations table
locations_Schema = StructType([
    StructField("LocationId", StringType(), True),
    StructField("OrganisationID", StringType(), True),
    StructField("LocationPostCode", StringType(), True)
])

# Define the schema for the NSPL21_AUG_2023_UK table
NSPL21_AUG_2023_UK_Schema = StructType([
    StructField("pcd", StringType(), True),
    StructField("pcd2", StringType(), True),
    StructField("pcds", StringType(), True),
    StructField("dointr", IntegerType(), True),
    StructField("doterm", IntegerType(), True),
    StructField("usertype", IntegerType(), True),
    StructField("oseast1m", IntegerType(), True),
    StructField("osnrth1m", IntegerType(), True),
    StructField("osgrdind", IntegerType(), True),
    StructField("oa21", StringType(), True),
    StructField("cty", StringType(), True),
    StructField("ced", StringType(), True),
    StructField("laua", StringType(), True),
    StructField("ward", StringType(), True),
    StructField("nhser", StringType(), True),
    StructField("ctry", StringType(), True),
    StructField("rgn", StringType(), True),
    StructField("pcon", StringType(), True),
    StructField("ttwa", StringType(), True),
    StructField("itl", StringType(), True),
    StructField("npark", StringType(), True),
    StructField("lsoa21", StringType(), True),
    StructField("msoa21", StringType(), True),
    StructField("wz11", StringType(), True),
    StructField("sicbl", StringType(), True),
    StructField("bua22", StringType(), True),
    StructField("ru11ind", StringType(), True),
    StructField("oac11", StringType(), True),
    StructField("lat", DoubleType(), True),
    StructField("long", DoubleType(), True),
    StructField("lep1", StringType(), True),
    StructField("lep2", StringType(), True),
    StructField("pfa", StringType(), True),
    StructField("imd", IntegerType(), True),
    StructField("icb", StringType(), True)
])

NSP21CL_AUG23_UK_LU_Schema = StructType([
    StructField("pcd7", StringType(), True),
    StructField("pcd8", StringType(), True),
    StructField("pcds", StringType(), True),
    StructField("dointr", IntegerType(), True),
    StructField("doterm", IntegerType(), True),
    StructField("usertype", IntegerType(), True),
    StructField("oseast1m", IntegerType(), True),
    StructField("osnrth1m", IntegerType(), True),
    StructField("oa21cd", StringType(), True),
    StructField("oac11cd", StringType(), True),
    StructField("oac11nm", StringType(), True),
    StructField("wz11cd", StringType(), True),
    StructField("wzc11cd", StringType(), True),
    StructField("wzc11nm", StringType(), True),
    StructField("lsoa21cd", StringType(), True),
    StructField("lsoa21nm", StringType(), True),
    StructField("msoa21cd", StringType(), True),
    StructField("msoa21nm", StringType(), True),
    StructField("soac11cd", StringType(), True),
    StructField("soac11nm", StringType(), True),
    StructField("ladcd", StringType(), True),
    StructField("ladnm", StringType(), True),
    StructField("ladnmw", StringType(), True),
    StructField("laccd", StringType(), True),
    StructField("lacnm", StringType(), True)
])

# %% [markdown]
# #### Read the Files

# %%
# Read the Locations
df_locations = spark.read \
    .format("com.crealytics.spark.excel") \
    .option("header", "true") \
    .schema(locations_Schema) \
    .load("Bronze/locations.xlsx")

df_locations.printSchema()
df_locations.show(5,truncate=False)

# Read the NSPL21_AUG_2023_UK
df_lookup_full = spark.read \
    .option("header", True) \
    .schema(NSPL21_AUG_2023_UK_Schema) \
    .csv("Bronze/NSPL21_AUG_2023_UK.csv")
    
df_lookup_full.printSchema()
df_lookup_full.show(5,truncate=False)

# Read the NSP21CL_AUG23_UK_LU
df_rural_lookup_full_CL = spark.read \
    .option("header", True) \
    .schema(NSP21CL_AUG23_UK_LU_Schema) \
    .csv("Bronze/NSP21CL_AUG23_UK_LU.csv")
    
df_rural_lookup_full_CL.printSchema()
df_rural_lookup_full_CL.show(5,truncate=False)
# Out:
# root
#  |-- LocationId: string (nullable = true)
#  |-- OrganisationID: string (nullable = true)
#  |-- LocationPostCode: string (nullable = true)
#
# +------------------------------------+------------------------------------+----------------+
# |LocationId                          |OrganisationID                      |LocationPostCode|
# +------------------------------------+------------------------------------+----------------+
# |d2587969-bb36-4f68-9718-1de5f95b3316|7e26597f-e458-4ced-a922-49fc04b17bc8|BB2 6PS         |
# |bb6febc5-b986-4a0b-b537-03a56fa321a4|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|LE11 2ER        |
# |ce0f066c-99dc-4fe2-aedd-4a61ffcf0c15|4aacc297-5d86-4032-9b42-09ad0575b2eb|H91 WR26        |
# |2a602313-0008-4b40-a345-207a553aafec|16cd29d4-e34a-49bd-b5bd-266b56a4f578|SA1 7LQ         |
# |ff7ba5dd-dfba-4f31-a1bc-335e3385e543|3eac8971-cdd4-4fd9-bc15-0f24cbaa439b|GL5 4JE         |
# +------------------------------------+------------------------------------+----------------+
# only showing top 5 rows
#
# root
#  |-- pcd: string (nullable = true)
#  |-- pcd2: string (nullable = true)
#  |-- pcds: string (nullable = true)
#  |-- dointr: integer (nullable = true)
#  |-- doterm: integer (nullable = true)
#  |-- usertype: integer (nullable = true)
#  |-- oseast1m: integer (nullable = true)
#  |-- osnrth1m: integer (nullable = true)
#  |-- osgrdind: integer (nullable = true)
#  |-- oa21: string (nullable = true)
#  |-- cty: string (nullable = true)
#  |-- ced: string (nullable = true)
#  |-- laua: string (nullable = true)
#  |-- ward: string (nullable = true)
#  |-- nhser: string (nullable = true)
#  |-- ctry: string (nullable = true)
#  |-- rgn: string (nullable = true)
#  |-- pcon: string (nullable = true)
#  |-- ttwa: string (nullable = true)
#  |-- itl: string (nullable = true)
#  |-- npark: string (nullable = true)
#  |-- lsoa21: string (nullable = true)
#  |-- msoa21: string (nullable = true)
#  |-- wz11: string (nullable = true)
#  |-- sicbl: string (nullable = true)
#  |-- bua22: string (nullable = true)
#  |-- ru11ind: string (nullable = true)
#  |-- oac11: string (nullable = true)
#  |-- lat: double (nullable = true)
#  |-- long: double (nullable = true)
#  |-- lep1: string (nullable = true)
#  |-- lep2: string (nullable = true)
#  |-- pfa: string (nullable = true)
#  |-- imd: integer (nullable = true)
#  |-- icb: string (nullable = true)
#
# +-------+--------+-------+------+------+--------+--------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+-------+-----+---------+---------+---------+----+---------+----+---------+
# |pcd    |pcd2    |pcds   |dointr|doterm|usertype|oseast1m|osnrth1m|osgrdind|oa21     |cty      |ced      |laua     |ward     |nhser    |ctry     |rgn      |pcon     |ttwa     |itl      |npark    |lsoa21   |msoa21   |wz11     |sicbl    |bua22    |ru11ind|oac11|lat      |long     |lep1     |lep2|pfa      |imd |icb      |
# +-------+--------+-------+------+------+--------+--------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+-------+-----+---------+---------+---------+----+---------+----+---------+
# |AB1 0AA|AB1  0AA|AB1 0AA|198001|199606|0       |385386  |801193  |1       |S00090303|S99999999|S99999999|S12000033|S13002843|S99999999|S92000003|S99999999|S14000002|S22000047|S30000026|S99999999|S01006514|S02001237|S34002990|S03000012|S99999999|3      |1C3  |57.101474|-2.242851|S99999999|NULL|S23000009|6715|S99999999|
# |AB1 0AB|AB1  0AB|AB1 0AB|198001|199606|0       |385177  |801314  |1       |S00090303|S99999999|S99999999|S12000033|S13002843|S99999999|S92000003|S99999999|S14000002|S22000047|S30000026|S99999999|S01006514|S02001237|S34002990|S03000012|S99999999|3      |1C3  |57.102554|-2.246308|S99999999|NULL|S23000009|6715|S99999999|
# |AB1 0AD|AB1  0AD|AB1 0AD|198001|199606|0       |385053  |801092  |1       |S00090399|S99999999|S99999999|S12000033|S13002843|S99999999|S92000003|S99999999|S14000002|S22000047|S30000026|S99999999|S01006514|S02001237|S34003015|S03000012|S99999999|3      |6A1  |57.100556|-2.248342|S99999999|NULL|S23000009|6715|S99999999|
# |AB1 0AE|AB1  0AE|AB1 0AE|199402|199606|0       |384600  |799300  |8       |S00091322|S99999999|S99999999|S12000034|S13002864|S99999999|S92000003|S99999999|S14000058|S22000047|S30000027|S99999999|S01006853|S02001296|S34003292|S03000013|S99999999|6      |1A2  |57.084444|-2.255708|S99999999|NULL|S23000009|5069|S99999999|
# |AB1 0AF|AB1  0AF|AB1 0AF|199012|199207|1       |384460  |800660  |8       |S00090299|S99999999|S99999999|S12000033|S13002843|S99999999|S92000003|S99999999|S14000002|S22000047|S30000026|S99999999|S01006511|S02001236|S34003015|S03000012|S99999999|3      |6A4  |57.096656|-2.258102|S99999999|NULL|S23000009|6253|S99999999|
# +-------+--------+-------+------+------+--------+--------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+-------+-----+---------+---------+---------+----+---------+----+---------+
# only showing top 5 rows
#
# root
#  |-- pcd7: string (nullable = true)
#  |-- pcd8: string (nullable = true)
#  |-- pcds: string (nullable = true)
#  |-- dointr: integer (nullable = true)
#  |-- doterm: integer (nullable = true)
#  |-- usertype: integer (nullable = true)
#  |-- oseast1m: integer (nullable = true)
#  |-- osnrth1m: integer (nullable = true)
#  |-- oa21cd: string (nullable = true)
#  |-- oac11cd: string (nullable = true)
#  |-- oac11nm: string (nullable = true)
#  |-- wz11cd: string (nullable = true)
#  |-- wzc11cd: string (nullable = true)
#  |-- wzc11nm: string (nullable = true)
#  |-- lsoa21cd: string (nullable = true)
#  |-- lsoa21nm: string (nullable = true)
#  |-- msoa21cd: string (nullable = true)
#  |-- msoa21nm: string (nullable = true)
#  |-- soac11cd: string (nullable = true)
#  |-- soac11nm: string (nullable = true)
#  |-- ladcd: string (nullable = true)
#  |-- ladnm: string (nullable = true)
#  |-- ladnmw: string (nullable = true)
#  |-- laccd: string (nullable = true)
#  |-- lacnm: string (nullable = true)
#
# +-------+--------+-------+------+------+--------+--------+--------+---------+-------+-------------------------------+---------+-------+------------------------------------+---------+--------+---------+--------+--------+---------------------------+---------+-------------+------+-----+-----------------------+
# |pcd7   |pcd8    |pcds   |dointr|doterm|usertype|oseast1m|osnrth1m|oa21cd   |oac11cd|oac11nm                        |wz11cd   |wzc11cd|wzc11nm                             |lsoa21cd |lsoa21nm|msoa21cd |msoa21nm|soac11cd|soac11nm                   |ladcd    |ladnm        |ladnmw|laccd|lacnm                  |
# +-------+--------+-------+------+------+--------+--------+--------+---------+-------+-------------------------------+---------+-------+------------------------------------+---------+--------+---------+--------+--------+---------------------------+---------+-------------+------+-----+-----------------------+
# |AB1 0AA|AB1  0AA|AB1 0AA|198001|199606|0       |385386  |801193  |S00090303|1C3    |Detached rural retirement      |S34002990|D1     |Non-metropolitan suburban areas     |S01006514|NULL    |S02001237|NULL    |8A      |Affluent communities       |S12000033|Aberdeen City|NULL  |2A1  |Larger Towns and Cities|
# |AB1 0AB|AB1  0AB|AB1 0AB|198001|199606|0       |385177  |801314  |S00090303|1C3    |Detached rural retirement      |S34002990|D1     |Non-metropolitan suburban areas     |S01006514|NULL    |S02001237|NULL    |8A      |Affluent communities       |S12000033|Aberdeen City|NULL  |2A1  |Larger Towns and Cities|
# |AB1 0AD|AB1  0AD|AB1 0AD|198001|199606|0       |385053  |801092  |S00090399|6A1    |Indian tech achievers          |S34003015|C1     |Teachers and carers in metro suburbs|S01006514|NULL    |S02001237|NULL    |8A      |Affluent communities       |S12000033|Aberdeen City|NULL  |2A1  |Larger Towns and Cities|
# |AB1 0AE|AB1  0AE|AB1 0AE|199402|199606|0       |384600  |799300  |S00091322|1A2    |Established farming communities|S34003292|F3     |Rural with mining or quarrying      |S01006853|NULL    |S02001296|NULL    |2B      |Prospering countryside life|S12000034|Aberdeenshire|NULL  |7A1  |Country Living         |
# |AB1 0AF|AB1  0AF|AB1 0AF|199012|199207|1       |384460  |800660  |S00090299|6A4    |Ageing in suburbia             |S34003015|C1     |Teachers and carers in metro suburbs|S01006511|NULL    |S02001236|NULL    |8B      |Ageing suburbanites        |S12000033|Aberdeen City|NULL  |2A1  |Larger Towns and Cities|
# +-------+--------+-------+------+------+--------+--------+--------+---------+-------+-------------------------------+---------+-------+------------------------------------+---------+--------+---------+--------+--------+---------------------------+---------+-------------+------+-----+-----------------------+
# only showing top 5 rows

# %% [markdown]
# ##### Count nulls and duplicates for each column in files

# %%
from pyspark.sql.functions import col, count, when

# Locations
null_counts = df_locations.select([count(when(col(c).isNull(), c)).alias(c) for c in df_locations.columns])
print("Number of nulls for each column:")
null_counts.show()

for c in df_locations.columns:
    duplicate_count = df_locations.groupBy(c).count().filter("`count` > 1").count()
    print(f"Number of duplicates in {c}: {duplicate_count}")
    
# NSPL21_AUG_2023_UK
df_lookup_full_null_counts = df_lookup_full.select([count(when(col(c).isNull(), c)).alias(c) for c in df_lookup_full.columns])
print("Number of nulls for each column:")
df_lookup_full_null_counts.show()
print("Number of duplicates for each column:")

duplicate_counts = {}

for c in df_lookup_full.columns:
    duplicates = df_lookup_full.groupBy(c).count().filter("`count` > 1").count()
    duplicate_counts[c] = duplicates

df_lookup_full_duplicate_counts = spark.createDataFrame(duplicate_counts.items(), schema=["Column", "DuplicateCount"])
df_lookup_full_duplicate_counts.show(n=30,truncate=False)

# NSP21CL_AUG23_UK_LU
df_rural_lookup_full_CL_null_counts = df_rural_lookup_full_CL.select([count(when(col(c).isNull(), c)).alias(c) for c in df_rural_lookup_full_CL.columns])
print("Number of nulls for each column:")
df_rural_lookup_full_CL_null_counts.show()
print("Number of duplicates for each column:")

duplicate_counts = {}

for c in df_rural_lookup_full_CL.columns:
    duplicates_rural_lookup_full_CL = df_rural_lookup_full_CL.groupBy(c).count().filter("`count` > 1").count()
    duplicate_counts[c] = duplicates_rural_lookup_full_CL

df_duplicate_counts_rural_lookup_full_CL = spark.createDataFrame(duplicate_counts.items(), schema=["Column", "DuplicateCount"])
df_duplicate_counts_rural_lookup_full_CL.show(truncate=False,n=30)
# Out:
# Number of nulls for each column:
# +----------+--------------+----------------+
# |LocationId|OrganisationID|LocationPostCode|
# +----------+--------------+----------------+
# |         0|             0|              72|
# +----------+--------------+----------------+
#
# Number of duplicates in LocationId: 0
# Number of duplicates in OrganisationID: 241
# Number of duplicates in LocationPostCode: 40
# Number of nulls for each column:
# +---+----+----+------+-------+--------+--------+--------+--------+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+-----+-----+-----+-------+-----+---+----+-----+-------+-----+---+-----+
# |pcd|pcd2|pcds|dointr| doterm|usertype|oseast1m|osnrth1m|osgrdind| oa21|  cty|  ced| laua| ward|nhser| ctry|  rgn| pcon| ttwa|  itl|npark|lsoa21|msoa21| wz11|sicbl|bua22|ru11ind|oac11|lat|long| lep1|   lep2|  pfa|imd|  icb|
# +---+----+----+------+-------+--------+--------+--------+--------+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+-----+-----+-----+-------+-----+---+----+-----+-------+-----+---+-----+
# |  0|   0|   0|     0|1796370|       0|   23901|   23901|       0|10805|10805|10805|10805|10805|10805|10799|10805|10805|10799|10805| 8083| 10805| 10799|10799|10805|10799|  70752|10799|  0|   0|10805|2656704|10805|  0|10805|
# +---+----+----+------+-------+--------+--------+--------+--------+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+-----+-----+-----+-------+-----+---+----+-----+-------+-----+---+-----+
#
# Number of duplicates for each column:
# +--------+--------------+
# |Column  |DuplicateCount|
# +--------+--------------+
# |pcd     |0             |
# |pcd2    |0             |
# |pcds    |0             |
# |dointr  |538           |
# |doterm  |415           |
# |usertype|2             |
# |oseast1m|347128        |
# |osnrth1m|397648        |
# |osgrdind|8             |
# |oa21    |230508        |
# |cty     |39            |
# |ced     |1579          |
# |laua    |377           |
# |ward    |8469          |
# |nhser   |13            |
# |ctry    |7             |
# |rgn     |15            |
# |pcon    |653           |
# |ttwa    |231           |
# |itl     |391           |
# |npark   |22            |
# |lsoa21  |43501         |
# |msoa21  |8547          |
# |wz11    |60707         |
# |sicbl   |155           |
# |bua22   |4171          |
# |ru11ind |20            |
# |oac11   |78            |
# |lat     |415937        |
# |long    |382086        |
# +--------+--------------+
# only showing top 30 rows
#
# Number of nulls for each column:
# +----+----+----+------+-------+--------+--------+--------+------+-------+-------+------+-------+-------+--------+--------+--------+--------+--------+--------+-----+-----+-------+------+------+
# |pcd7|pcd8|pcds|dointr| doterm|usertype|oseast1m|osnrth1m|oa21cd|oac11cd|oac11nm|wz11cd|wzc11cd|wzc11nm|lsoa21cd|lsoa21nm|msoa21cd|msoa21nm|soac11cd|soac11nm|ladcd|ladnm| ladnmw| laccd| lacnm|
# +----+----+----+------+-------+--------+--------+--------+------+-------+-------+------+-------+-------+--------+--------+--------+--------+--------+--------+-----+-----+-------+------+------+
# |   0|   0|   0|     0|1796370|       0|   23901|   23901| 10805|  10799|  10799| 10799|  10799|  10799|   10805|  312978|   10799|  312238|  230421|  230421|10805|10805|2553918|119222|119222|
# +----+----+----+------+-------+--------+--------+--------+------+-------+-------+------+-------+-------+--------+--------+--------+--------+--------+--------+-----+-----+-------+------+------+
#
# Number of duplicates for each column:
# +--------+--------------+
# |Column  |DuplicateCount|
# +--------+--------------+
# |pcd7    |0             |
# |pcd8    |0             |
# |pcds    |0             |
# |dointr  |538           |
# |doterm  |415           |
# |usertype|2             |
# |oseast1m|347128        |
# |osnrth1m|397648        |
# |oa21cd  |230508        |
# |oac11cd |78            |
# |oac11nm |78            |
# |wz11cd  |60707         |
# |wzc11cd |31            |
# |wzc11nm |31            |
# |lsoa21cd|43501         |
# |lsoa21nm|35669         |
# |msoa21cd|8547          |
# |msoa21nm|7264          |
# |soac11cd|26            |
# |soac11nm|26            |
# |ladcd   |377           |
# |ladnm   |377           |
# |ladnmw  |23            |
# |laccd   |26            |
# |lacnm   |26            |
# +--------+--------------+

# %% [markdown]
# #### Add NK (Not Known) for null values in the files where necessary

# %%
# Add NK (Not Known) for null values in LocationPostCode column 
df_locations_NK = df_locations.fillna("NK", subset=["LocationPostCode"])
df_locations_NK.show(5)

df_filtered_LocationPostCode_NK = df_locations.filter(df_locations["LocationPostCode"] == "NK")
df_filtered_LocationPostCode_NK.show(5)

# Add NK (Not Known) for null values in ladnm column 
df_rural_lookup_full_CL_NK = df_rural_lookup_full_CL.fillna("NK", subset=["ladnm"])
df_rural_lookup_full_CL_NK.show(5)

df_filtered_ladnm = df_rural_lookup_full_CL.filter(df_rural_lookup_full_CL["ladnm"] == "NK")
df_filtered_ladnm.show(5)

# Add NK (Not Known) for null values in ru11ind column 
df_lookup_full_NK = df_lookup_full.fillna("NK", subset=["ru11ind"])
df_lookup_full_NK.show(5)

df_filtered_ru11ind_NK = df_lookup_full.filter(df_lookup_full["ru11ind"] == "NK")
df_filtered_ru11ind_NK.show(5)
# Out:
# +--------------------+--------------------+----------------+
# |          LocationId|      OrganisationID|LocationPostCode|
# +--------------------+--------------------+----------------+
# |d2587969-bb36-4f6...|7e26597f-e458-4ce...|         BB2 6PS|
# |bb6febc5-b986-4a0...|b69d7b9d-998e-4be...|        LE11 2ER|
# |ce0f066c-99dc-4fe...|4aacc297-5d86-403...|        H91 WR26|
# |2a602313-0008-4b4...|16cd29d4-e34a-49b...|         SA1 7LQ|
# |ff7ba5dd-dfba-4f3...|3eac8971-cdd4-4fd...|         GL5 4JE|
# +--------------------+--------------------+----------------+
# only showing top 5 rows
#
# +----------+--------------+----------------+
# |LocationId|OrganisationID|LocationPostCode|
# +----------+--------------+----------------+
# +----------+--------------+----------------+
#
# +-------+--------+-------+------+------+--------+--------+--------+---------+-------+--------------------+---------+-------+--------------------+---------+--------+---------+--------+--------+--------------------+---------+-------------+------+-----+--------------------+
# |   pcd7|    pcd8|   pcds|dointr|doterm|usertype|oseast1m|osnrth1m|   oa21cd|oac11cd|             oac11nm|   wz11cd|wzc11cd|             wzc11nm| lsoa21cd|lsoa21nm| msoa21cd|msoa21nm|soac11cd|            soac11nm|    ladcd|        ladnm|ladnmw|laccd|               lacnm|
# +-------+--------+-------+------+------+--------+--------+--------+---------+-------+--------------------+---------+-------+--------------------+---------+--------+---------+--------+--------+--------------------+---------+-------------+------+-----+--------------------+
# |AB1 0AA|AB1  0AA|AB1 0AA|198001|199606|       0|  385386|  801193|S00090303|    1C3|Detached rural re...|S34002990|     D1|Non-metropolitan ...|S01006514|    NULL|S02001237|    NULL|      8A|Affluent communities|S12000033|Aberdeen City|  NULL|  2A1|Larger Towns and ...|
# |AB1 0AB|AB1  0AB|AB1 0AB|198001|199606|       0|  385177|  801314|S00090303|    1C3|Detached rural re...|S34002990|     D1|Non-metropolitan ...|S01006514|    NULL|S02001237|    NULL|      8A|Affluent communities|S12000033|Aberdeen City|  NULL|  2A1|Larger Towns and ...|
# |AB1 0AD|AB1  0AD|AB1 0AD|198001|199606|       0|  385053|  801092|S00090399|    6A1|Indian tech achie...|S34003015|     C1|Teachers and care...|S01006514|    NULL|S02001237|    NULL|      8A|Affluent communities|S12000033|Aberdeen City|  NULL|  2A1|Larger Towns and ...|
# |AB1 0AE|AB1  0AE|AB1 0AE|199402|199606|       0|  384600|  799300|S00091322|    1A2|Established farmi...|S34003292|     F3|Rural with mining...|S01006853|    NULL|S02001296|    NULL|      2B|Prospering countr...|S12000034|Aberdeenshire|  NULL|  7A1|      Country Living|
# |AB1 0AF|AB1  0AF|AB1 0AF|199012|199207|       1|  384460|  800660|S00090299|    6A4|  Ageing in suburbia|S34003015|     C1|Teachers and care...|S01006511|    NULL|S02001236|    NULL|      8B| Ageing suburbanites|S12000033|Aberdeen City|  NULL|  2A1|Larger Towns and ...|
# +-------+--------+-------+------+------+--------+--------+--------+---------+-------+--------------------+---------+-------+--------------------+---------+--------+---------+--------+--------+--------------------+---------+-------------+------+-----+--------------------+
# only showing top 5 rows
# +----+----+----+------+------+--------+--------+--------+------+-------+-------+------+-------+-------+--------+--------+--------+--------+--------+--------+-----+-----+------+-----+-----+
# |pcd7|pcd8|pcds|dointr|doterm|usertype|oseast1m|osnrth1m|oa21cd|oac11cd|oac11nm|wz11cd|wzc11cd|wzc11nm|lsoa21cd|lsoa21nm|msoa21cd|msoa21nm|soac11cd|soac11nm|ladcd|ladnm|ladnmw|laccd|lacnm|
# +----+----+----+------+------+--------+--------+--------+------+-------+-------+------+-------+-------+--------+--------+--------+--------+--------+--------+-----+-----+------+-----+-----+
# +----+----+----+------+------+--------+--------+--------+------+-------+-------+------+-------+-------+--------+--------+--------+--------+--------+--------+-----+-----+------+-----+-----+
#
# +-------+--------+-------+------+------+--------+--------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+-------+-----+---------+---------+---------+----+---------+----+---------+
# |    pcd|    pcd2|   pcds|dointr|doterm|usertype|oseast1m|osnrth1m|osgrdind|     oa21|      cty|      ced|     laua|     ward|    nhser|     ctry|      rgn|     pcon|     ttwa|      itl|    npark|   lsoa21|   msoa21|     wz11|    sicbl|    bua22|ru11ind|oac11|      lat|     long|     lep1|lep2|      pfa| imd|      icb|
# +-------+--------+-------+------+------+--------+--------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+-------+-----+---------+---------+---------+----+---------+----+---------+
# |AB1 0AA|AB1  0AA|AB1 0AA|198001|199606|       0|  385386|  801193|       1|S00090303|S99999999|S99999999|S12000033|S13002843|S99999999|S92000003|S99999999|S14000002|S22000047|S30000026|S99999999|S01006514|S02001237|S34002990|S03000012|S99999999|      3|  1C3|57.101474|-2.242851|S99999999|NULL|S23000009|6715|S99999999|
# |AB1 0AB|AB1  0AB|AB1 0AB|198001|199606|       0|  385177|  801314|       1|S00090303|S99999999|S99999999|S12000033|S13002843|S99999999|S92000003|S99999999|S14000002|S22000047|S30000026|S99999999|S01006514|S02001237|S34002990|S03000012|S99999999|      3|  1C3|57.102554|-2.246308|S99999999|NULL|S23000009|6715|S99999999|
# |AB1 0AD|AB1  0AD|AB1 0AD|198001|199606|       0|  385053|  801092|       1|S00090399|S99999999|S99999999|S12000033|S13002843|S99999999|S92000003|S99999999|S14000002|S22000047|S30000026|S99999999|S01006514|S02001237|S34003015|S03000012|S99999999|      3|  6A1|57.100556|-2.248342|S99999999|NULL|S23000009|6715|S99999999|
# |AB1 0AE|AB1  0AE|AB1 0AE|199402|199606|       0|  384600|  799300|       8|S00091322|S99999999|S99999999|S12000034|S13002864|S99999999|S92000003|S99999999|S14000058|S22000047|S30000027|S99999999|S01006853|S02001296|S34003292|S03000013|S99999999|      6|  1A2|57.084444|-2.255708|S99999999|NULL|S23000009|5069|S99999999|
# |AB1 0AF|AB1  0AF|AB1 0AF|199012|199207|       1|  384460|  800660|       8|S00090299|S99999999|S99999999|S12000033|S13002843|S99999999|S92000003|S99999999|S14000002|S22000047|S30000026|S99999999|S01006511|S02001236|S34003015|S03000012|S99999999|      3|  6A4|57.096656|-2.258102|S99999999|NULL|S23000009|6253|S99999999|
# +-------+--------+-------+------+------+--------+--------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+-------+-----+---------+---------+---------+----+---------+----+---------+
# only showing top 5 rows
# [Stage 832:>                                                        (0 + 3) / 3]
# +---+----+----+------+------+--------+--------+--------+--------+----+---+---+----+----+-----+----+---+----+----+---+-----+------+------+----+-----+-----+-------+-----+---+----+----+----+---+---+---+
# |pcd|pcd2|pcds|dointr|doterm|usertype|oseast1m|osnrth1m|osgrdind|oa21|cty|ced|laua|ward|nhser|ctry|rgn|pcon|ttwa|itl|npark|lsoa21|msoa21|wz11|sicbl|bua22|ru11ind|oac11|lat|long|lep1|lep2|pfa|imd|icb|
# +---+----+----+------+------+--------+--------+--------+--------+----+---+---+----+----+-----+----+---+----+----+---+-----+------+------+----+-----+-----+-------+-----+---+----+----+----+---+---+---+
# +---+----+----+------+------+--------+--------+--------+--------+----+---+---+----+----+-----+----+---+----+----+---+-----+------+------+----+-----+-----+-------+-----+---+----+----+----+---+---+---+

# %% [markdown]
# #### Clean the columns have the post codes

# %%
from pyspark.sql.functions import col, regexp_replace, trim, length, when

# Cleaning and flagging for df_locations_NK
df_locations_cleaned = df_locations_NK.withColumn("LocationPostCode_clean",
                                                  regexp_replace(col("LocationPostCode"), "\\s+", "")) \
                                       .withColumn("LocationPostCode_clean",
                                                   regexp_replace(col("LocationPostCode_clean"), "[\\p{Punct}]", "")) \
                                       .withColumn("LocationPostCode_clean",
                                                   trim(col("LocationPostCode_clean"))) \
                                       .withColumn("valid_LocationPostCode",
                                                   when((length(col("LocationPostCode_clean")) >= 5) & 
                                                        (length(col("LocationPostCode_clean")) <= 8), True)
                                                   .otherwise(False))

df_locations_cleaned.show(n=1600,truncate=False)
df_locations_cleaned.filter(col("valid_LocationPostCode") == False).show(truncate=False)

# Cleaning and flagging for df_rural_lookup_full_CL_NK
df_rural_lookup_full_CL_cleaned = df_rural_lookup_full_CL_NK.withColumn("pcds_clean",
                                                                        regexp_replace(col("pcds"), "\\s+", "")) \
                                                             .withColumn("pcds_clean",
                                                                         regexp_replace(col("pcds_clean"), "[\\p{Punct}]", "")) \
                                                             .withColumn("pcds_clean",
                                                                         trim(col("pcds_clean"))) \
                                                             .withColumn("valid_pcds",
                                                                         when((length(col("pcds_clean")) >= 5) & 
                                                                              (length(col("pcds_clean")) <= 8), True)
                                                                         .otherwise(False))

df_rural_lookup_full_CL_cleaned.show(5,truncate=False)
df_rural_lookup_full_CL_cleaned.filter(col("valid_pcds") == False).show(truncate=False)

# Cleaning and flagging for df_lookup_full_NK
df_lookup_full_CL_cleaned = df_lookup_full_NK.withColumn("pcds_clean",
                                                         regexp_replace(col("pcds"), "\\s+", "")) \
                                              .withColumn("pcds_clean",
                                                          regexp_replace(col("pcds_clean"), "[\\p{Punct}]", "")) \
                                              .withColumn("pcds_clean",
                                                          trim(col("pcds_clean"))) \
                                              .withColumn("valid_pcds",
                                                          when((length(col("pcds_clean")) >= 5) & 
                                                               (length(col("pcds_clean")) <= 8), True)
                                                          .otherwise(False))

df_lookup_full_CL_cleaned.show(5,truncate=False)
df_lookup_full_CL_cleaned.filter(col("valid_pcds") == False).show()
# Out:
# +------------------------------------+------------------------------------+----------------+----------------------+----------------------+
# |LocationId                          |OrganisationID                      |LocationPostCode|LocationPostCode_clean|valid_LocationPostCode|
# +------------------------------------+------------------------------------+----------------+----------------------+----------------------+
# |d2587969-bb36-4f68-9718-1de5f95b3316|7e26597f-e458-4ced-a922-49fc04b17bc8|BB2 6PS         |BB26PS                |true                  |
# |bb6febc5-b986-4a0b-b537-03a56fa321a4|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|LE11 2ER        |LE112ER               |true                  |
# |ce0f066c-99dc-4fe2-aedd-4a61ffcf0c15|4aacc297-5d86-4032-9b42-09ad0575b2eb|H91 WR26        |H91WR26               |true                  |
# |2a602313-0008-4b40-a345-207a553aafec|16cd29d4-e34a-49bd-b5bd-266b56a4f578|SA1 7LQ         |SA17LQ                |true                  |
# |ff7ba5dd-dfba-4f31-a1bc-335e3385e543|3eac8971-cdd4-4fd9-bc15-0f24cbaa439b|GL5 4JE         |GL54JE                |true                  |
# |6ee14b6c-37dc-4293-9454-d01b5b66bc97|5918c36f-fb48-490a-9c6b-0f64a0670681|L4 8UD          |L48UD                 |true                  |
# |1229c04f-7d28-4565-847a-62c32baf31b2|2feff59d-ca15-49a0-9100-165cded25a37|RG457HU         |RG457HU               |true                  |
# |0df7260f-9c7e-49f3-a646-eb528abbf496|2feff59d-ca15-49a0-9100-165cded25a37|NN15 7HW        |NN157HW               |true                  |
# |986801e2-19b2-4d39-b215-7e72376ad76f|e6633b0f-d89f-4e7e-92b4-7f73f059e6c5|CV5 9AZ         |CV59AZ                |true                  |
# |27f9031c-81e4-46ee-a8be-c84bca603f00|16cd29d4-e34a-49bd-b5bd-266b56a4f578|SA1 7LQ         |SA17LQ                |true                  |
# |bb26c9b8-220a-416d-977d-a6dee356957b|99b10abb-dcee-4b52-a63c-5852cce8edd3|S45 9AQ         |S459AQ                |true                  |
# |163c2ce7-8a70-4010-99eb-2b29d510dd6a|be74d05d-3198-4627-b1d3-40a63ee395ed|WS10 9AX        |WS109AX               |true                  |
# |4be5b3cf-a61c-4025-829e-0416a9c1244e|851d1549-6dd7-4aa3-aeb1-fb4f699f5546|ME8 0EQ         |ME80EQ                |true                  |
# |6349cf74-7f04-4e87-b9bc-35721d41510d|a6e3b390-2e1e-4203-a0a8-973f9221b408|PR4 0AP         |PR40AP                |true                  |
# |39ac977c-f0f9-4c6e-a71c-508ea82533c5|3eefd529-51ec-4929-8955-36731d84fbfe|SK6 6PA         |SK66PA                |true                  |
# |760fd376-1d15-44cd-a0f3-535bb0a1763a|8eef668d-319a-45c8-aaa4-3b6e603e7773|L35 7LS         |L357LS                |true                  |
# |539651a0-defc-46b2-bd92-c4f98afdbfb4|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|WF10 4BJ        |WF104BJ               |true                  |
# |3e0f4813-7ae3-4ace-b6fe-7eccac65d891|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|WN2 4DT         |WN24DT                |true                  |
# |dd033180-c6b6-46c1-90b1-cecec0aa9fcd|03b64589-2ccd-4dbd-92fc-7e2fb25530cb|HR1 1TH         |HR11TH                |true                  |
# |2a3024b1-31e1-474c-ac1e-b6cb1d2277e0|f63863e6-e15a-4d7c-bd2e-c05369d5bac7|YO17 9DP        |YO179DP               |true                  |
# |8f42bbcb-b1e1-49a9-9e28-cd62137aed47|ebb33b63-ab48-4fe5-be2a-5527ed7e0f86|MK15 0AA        |MK150AA               |true                  |
# |df358310-7f4f-450a-af30-3a52061c5b1c|0f18dbc7-3ca0-432a-bc88-568019e002ca|ML11 8QP        |ML118QP               |true                  |
# |3881bacb-350e-4774-b4e2-e2aedb9fddf3|57afcbb5-ab1c-4158-a8d7-59489efa051e|BN13 3EA        |BN133EA               |true                  |
# |997e057f-f988-4156-a4d0-0b4c745827b1|36afdf64-29ee-45ee-93ca-ed0eef9d78b5|EX17 3BS        |EX173BS               |true                  |
# |4fb705ca-cef1-4b57-a24a-18ed687c88ff|34744739-3a89-47f5-8d9f-73310d3a5025|GU23 7DJ        |GU237DJ               |true                  |
# |88eadb23-8ad4-49d9-823f-c7cfe248d75d|59ccb050-9c99-4914-b62b-be2d1fbbd84e|TN18 5EF        |TN185EF               |true                  |
# |7a6c643c-11e4-471d-adbc-607423e26186|332b86c9-cb30-4500-81d4-86abfec2f980|ML3 9AB         |ML39AB                |true                  |
# |31906383-d5af-4803-86cb-4cd717b340d7|9b939a1e-0462-47c4-8f2f-89f396e12e58|S72 8NP         |S728NP                |true                  |
# |63beabd5-545b-4eaa-b073-b82377080683|59ccb050-9c99-4914-b62b-be2d1fbbd84e|TN2 4QS         |TN24QS                |true                  |
# |6530cbb8-5f9d-4b54-ad54-d08ef6c38ec9|ae6143b2-9e68-4b6e-abfe-e4701c064dfa|BN11 2AE        |BN112AE               |true                  |
# |051a6913-3833-482e-a61f-460bedd40023|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|DN33 1NU        |DN331NU               |true                  |
# |fb5d2938-6fbd-4ebf-a75e-6c5371aeeee5|aa532354-1e4d-40d5-b493-3bc939b58cfa|WF5 9RL         |WF59RL                |true                  |
# |e32e2089-d8af-4a1c-a07b-5d7a65ec49f7|99b10abb-dcee-4b52-a63c-5852cce8edd3|CV4 9GN         |CV49GN                |true                  |
# |aca14482-8b47-4565-bede-f2430f27536d|59e6a743-4540-412c-862d-7c2c0d150ec7|IP2 0QR         |IP20QR                |true                  |
# |15a12967-adca-4f14-bce0-6259f7cf8fa8|e13ff36f-06f8-46ea-b039-60b92266835f|SO31 7EW        |SO317EW               |true                  |
# |ed673bd1-9998-4afc-967a-455fcd927820|fd7c7206-1b4e-41f1-a8de-24abf58efa8c|BH25 7EJ        |BH257EJ               |true                  |
# |5eebaa83-55c1-47f9-abb2-bcb269d02b87|e2b2cac7-5edd-428a-b892-8f510c6a43b6|RH2 9DB         |RH29DB                |true                  |
# |cc2cdcb6-05c3-43d6-bb7d-f4251f58a212|a97c8f2b-4ba3-4b18-b77b-dce09488ed4e|LS28 7UB        |LS287UB               |true                  |
# |bed4156c-a419-4383-8dfd-71dd864095b9|2feff59d-ca15-49a0-9100-165cded25a37|HP23 4DH        |HP234DH               |true                  |
# |84b772f5-30d0-48cf-ad77-245ae9cb918a|0804ed17-e1cf-4b22-8e9b-b851606e3814|RG2 7RU         |RG27RU                |true                  |
# |75a899af-9b92-46ee-b8d4-1031c01b4619|ec8980bd-e48b-4e97-bb40-425d2a0c401a|TQ14 8LA        |TQ148LA               |true                  |
# |223689e2-d204-4a19-b1bc-0e3b2179e552|a6f3f04f-db77-41a7-a890-6a11604947b9|DE5 9QT         |DE59QT                |true                  |
# |9de8bbcb-1c24-432d-b092-667a580c49ae|daadc87f-a2d1-4b96-8123-0a4ddac093db|TN12 5EN        |TN125EN               |true                  |
# |3700872a-5ff4-4548-9d01-6a4a24d41aae|4525390c-c86e-4fce-804d-f46431fea365|TN38 0SE        |TN380SE               |true                  |
# |f62e8af5-a10f-4e21-9aa4-f40fc2da2597|332b86c9-cb30-4500-81d4-86abfec2f980|DD4 8ER         |DD48ER                |true                  |
# |1c9a142f-8f91-4aa8-bde5-874446029d7e|c63407c7-798b-45ab-9a82-b5091c393494|LU1 4BJ         |LU14BJ                |true                  |
# |ac985625-c158-4a9b-b194-adb6f76e5639|ed16f2db-cd29-4944-8357-f029bda1938b|LU2 7QF         |LU27QF                |true                  |
# |bb5f3b2a-19a7-4fc9-8b1c-2f6c5d56049b|be74d05d-3198-4627-b1d3-40a63ee395ed|WS4 1SA         |WS41SA                |true                  |
# |e7bc199f-7801-4420-891b-3682e03869c8|7157418a-6595-463c-8824-d943ffc3016d|RH1 5PA         |RH15PA                |true                  |
# |74c6b726-b3b7-44d5-baad-01f23a93b714|ae6143b2-9e68-4b6e-abfe-e4701c064dfa|TQ1 2PX         |TQ12PX                |true                  |
# |819861dc-83e2-466b-b551-56e1c5e41f1c|8aea0b90-f92f-4b04-8e5e-a2ec531f6fe3|SW12 8NB        |SW128NB               |true                  |
# |dd351829-d79d-4a6c-af63-98db268049c8|c94e6850-c754-473e-985a-29169d71b602|RG4 9RG         |RG49RG                |true                  |
# |7173305d-061e-4be6-873e-52e825fc57c0|81846633-e174-46fb-9e95-b550f17295b0|WV2 4PZ         |WV24PZ                |true                  |
# |17fb436e-3a7b-41d1-a975-8451d29e7183|ca4daf40-c6eb-4ec3-be6e-0f108942dc64|NR32 3AA        |NR323AA               |true                  |
# |bfcc389c-beb3-4a69-8d32-36ba313895bd|6b7ea3ef-d395-4167-8bc2-e83b45fdb474|CT9 2LL         |CT92LL                |true                  |
# |48c1ebc5-8137-45b4-8105-1f3a2155fa09|89c9b63d-ebbe-4b77-88a8-086a55d8a50d|CM23 1EN        |CM231EN               |true                  |
# |22d68cc7-5437-4dc6-b607-5f1858c835c5|470775e7-0b64-46df-a671-07ccd30bb9a0|SO23 7BE        |SO237BE               |true                  |
# |9e9f9920-a86c-4c11-9b74-23cdcde52e32|318eddb1-dcf8-4a7f-b6e9-781100f3dd96|HU8 9EH         |HU89EH                |true                  |
# |7d1a1c74-2dab-4b21-a04f-9584f9f9aac6|6a97769e-9ce8-4789-a220-b69eb29a0fbd|TN34 2RA        |TN342RA               |true                  |
# |e7207278-486a-4cb8-9cd6-1260c2a40625|aeb5acfe-7c49-45c4-8825-f987a950f716|RM17 5RR        |RM175RR               |true                  |
# |450b97bd-9cca-44d2-b7e2-64ca50ae402b|318eddb1-dcf8-4a7f-b6e9-781100f3dd96|ST14 8JT        |ST148JT               |true                  |
# |c77628cc-255e-4d39-baa4-fc1702415bdd|a6e3b390-2e1e-4203-a0a8-973f9221b408|SK6 4JA         |SK64JA                |true                  |
# |aaf377e5-3a38-4e4f-84c0-94407eb832f6|ac62dd7c-eb46-4922-84cd-2f4b1d231280|SK5 8BS         |SK58BS                |true                  |
# |d92e794f-2913-4ad9-ae3c-3c75c36bdca1|01b4acb5-528f-4da9-a58f-eb71eb04e386|UB10 0BY        |UB100BY               |true                  |
# |838a2016-1aaa-4a47-bcb9-9edbea6d0840|351e396c-7981-429f-81fa-c70ef97f9fc4|BL1 5BB         |BL15BB                |true                  |
# |2c140c71-e0ea-4818-92a6-eba38c185824|3eefd529-51ec-4929-8955-36731d84fbfe|SK6 3AU         |SK63AU                |true                  |
# |b843a3a4-095d-4ce7-88ad-e0e91f4ba975|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|NG24 4DF        |NG244DF               |true                  |
# |63e33621-27a1-405b-b174-62ad5df41162|8a02ddc6-2f42-4848-8540-a7c183f0983b|RG28 7DX        |RG287DX               |true                  |
# |aa80b62d-32d5-43fd-8704-bc945139d617|ca4daf40-c6eb-4ec3-be6e-0f108942dc64|WA16 8AQ        |WA168AQ               |true                  |
# |03105ac2-0789-4d2c-b1af-8d0e323b585f|346645a7-7bb9-418e-8c56-70f8b3a2cd77|PE21 9EG        |PE219EG               |true                  |
# |8ce6b7e6-d515-4d03-ad5b-77c9ac48f662|1d8e8a92-09a2-4f99-85e8-687415c9fe00|IV49 9AB        |IV499AB               |true                  |
# |68cb9234-feae-4648-afd7-6a384e15195b|c7a0c429-ac15-41d4-a92e-6f24a5ef8def| DE75 7AQ       |DE757AQ               |true                  |
# |a434b387-5439-4286-8c7d-29d98d2e90fc|bdbc4693-4d98-4d96-b9a3-4dc0162818f4|B79 7SF         |B797SF                |true                  |
# |5c1d13ae-e0c3-40bd-ba01-0982584ae1b2|23cbd005-ee53-4634-bc9c-34495ae89667|NN5 6FR         |NN56FR                |true                  |
# |aaa132fd-b495-4390-b5d3-59579dae0429|b5ce10ba-4905-47b6-a5fc-6c75f08abf6e|PR8 6PD         |PR86PD                |true                  |
# |ffa95965-e351-4afa-87bf-4568f45fe258|0024651d-df55-4cda-af53-af55591f4e30|NG16 6AB        |NG166AB               |true                  |
# |249682b2-e7f7-4c07-a023-d1a452343e16|afcc2f69-e61a-46e4-8560-3f57cab67010|AB54 8TS        |AB548TS               |true                  |
# |41903e3c-ca11-486a-b724-070faa0c1ba6|7c68afee-9f31-473d-a11f-604d118a21e4|CV21 3HX        |CV213HX               |true                  |
# |012a112e-cdc4-49b8-a795-830e16dd2456|f828d521-dba4-4a94-8720-3fd69fa9d1d1|E1 4NA          |E14NA                 |true                  |
# |2063ba27-7f59-403d-95a9-e193d928433b|18c6698a-b3f4-4aa6-96e9-f5a08015e275|N1 7RY          |N17RY                 |true                  |
# |7187f0ac-b8f2-4f06-87ba-472aff3afa5e|b40d4864-7711-43cc-90f5-5b64a100f918|PR26 9RA        |PR269RA               |true                  |
# |5edcf390-ace9-4c85-bcf9-1a98331ff2aa|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|LE4 2BD         |LE42BD                |true                  |
# |17153e81-359e-4b53-92a1-b9f2627fa05c|593f84d4-f5a9-4a1e-bacd-2e36bba51072|S41 7HR         |S417HR                |true                  |
# |418e9704-a2bf-4b08-bd86-12640e2e9f3d|30e9b3ea-c37b-4939-8cb7-1c152677e1f5|TN14 7AG        |TN147AG               |true                  |
# |69462ea8-bceb-4264-863c-17e700383c71|e2b2cac7-5edd-428a-b892-8f510c6a43b6|GU26 6TJ        |GU266TJ               |true                  |
# |50b47f5a-9eda-40d5-b157-41690b118709|9699a789-b6c3-48bb-a080-6400edb8e4f0|BH23 7JU        |BH237JU               |true                  |
# |dcf5705b-43b7-45b6-91e7-72053283fd3a|cc10c478-febc-4bbb-84e9-842621ce3ce8|B65 0PP         |B650PP                |true                  |
# |329c2b64-2008-4338-b763-1c277d411a77|ff8dae68-b32c-4853-af44-54cddb18ae6e|SG4 9RW         |SG49RW                |true                  |
# |716fcc71-195f-4eed-b743-dc16e641ad27|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|M41 6NA         |M416NA                |true                  |
# |42159437-3125-4802-a9c7-327c9f15636f|99b10abb-dcee-4b52-a63c-5852cce8edd3|LE10 2AW        |LE102AW               |true                  |
# |08424612-ea03-419b-821b-441fdec9857c|9e7368f3-43e0-4330-bd6b-3ecf55726827|DD6 8HD         |DD68HD                |true                  |
# |cdf00c5e-fa09-4c9c-a7e4-63cea42ec986|43ae1eca-1304-4f6d-bc01-e7583212644c|LU7 1SD         |LU71SD                |true                  |
# |2cbdfccc-4a9d-490c-b16b-6ea2c71724ce|2c446490-7c17-4cef-8420-db4dea3ecaaf|NN4 6JR         |NN46JR                |true                  |
# |9e4232c5-c73c-4f6e-b6e1-d4c3194c4090|93b513d8-5135-4d59-8ff0-547845d06e53|TQ3 2HS         |TQ32HS                |true                  |
# |f9fabb9a-4697-4b7f-8b3e-ca54d8b1c905|144c3c08-3ada-4913-8520-5b60d545e60a|S64 8LU         |S648LU                |true                  |
# |b4aacfd1-6828-4129-bdb9-85fc8753501c|a97c8f2b-4ba3-4b18-b77b-dce09488ed4e|S71 5QU         |S715QU                |true                  |
# |59e1dab8-3dc5-4c3f-bb4c-272d90dab493|a3fbd3a7-481e-460d-80d3-58f1d010620e|M46 0EU         |M460EU                |true                  |
# |ae7b91ac-49e3-4ba5-838f-c1cf38ddd367|fe38979b-0ec8-4962-92d1-db1e9857b25f|M30 9BA         |M309BA                |true                  |
# |615af906-ea43-4a77-aa88-fb9948c27795|8b64eb03-47f0-4fd5-a0e6-318408d7b797|HR1 9TS         |HR19TS                |true                  |
# |787309f5-59bf-4f73-89ce-52550e8c8303|6c189628-56ba-4874-959d-6b626a0b7d59|RH1 4BG         |RH14BG                |true                  |
# |01aa9997-6ca5-457a-b304-214801e3bd48|ed16f2db-cd29-4944-8357-f029bda1938b|TW14 9AY        |TW149AY               |true                  |
# |06e600c8-6148-4a18-bdd8-0f10586f7990|2feff59d-ca15-49a0-9100-165cded25a37|EN4 0PH         |EN40PH                |true                  |
# |5de4e4d8-01ab-4ed6-bea1-96458a0745f5|174f8be8-948d-4910-aab9-2a06c1d14800|MK41 0JX        |MK410JX               |true                  |
# |6eb05ba5-928e-4ba0-a599-f658361d3b10|5ca719be-76e1-4217-aaa0-0c8b443caafe|LS25 1EP        |LS251EP               |true                  |
# |6893503e-b17b-4fa2-b8d9-66a9840af483|f784beac-ef01-46f0-9ba9-c7e3bcfc0df8|WF7 6HD         |WF76HD                |true                  |
# |ecc8124b-7989-4c5b-b9a4-af12079db5c8|ed16f2db-cd29-4944-8357-f029bda1938b|IG2 6PS         |IG26PS                |true                  |
# |ffb6f0c8-18c8-4a02-aff9-9270a406ce30|f56db364-2814-43b2-b049-62edcbd20912|BR8 7FP         |BR87FP                |true                  |
# |813b0370-6fff-4276-b72c-6079b4f054d4|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|M24 5QH         |M245QH                |true                  |
# |9aa47df7-94c5-4387-9b34-9b6cb58c0702|593f84d4-f5a9-4a1e-bacd-2e36bba51072|DE23 6AF        |DE236AF               |true                  |
# |db368f73-54ed-4218-bf6d-ec82597fa7b9|ca4daf40-c6eb-4ec3-be6e-0f108942dc64|MK40 2DW        |MK402DW               |true                  |
# |4a934f40-35bd-481e-85a1-5c9bd6ccbe4d|ac5d475e-0f23-4ea7-87ae-a67bbbc4e8fd|LN6 5UW         |LN65UW                |true                  |
# |3fe3a937-035e-44a0-920a-aec04d334e82|f828d521-dba4-4a94-8720-3fd69fa9d1d1|CH42 1NZ        |CH421NZ               |true                  |
# |e6dcf7b6-5f53-450d-a94f-cc28db6b6280|ac5d475e-0f23-4ea7-87ae-a67bbbc4e8fd|SK17 6XJ        |SK176XJ               |true                  |
# |a28dad26-f4ad-4fa2-91cb-69b300bc41b0|e2b2cac7-5edd-428a-b892-8f510c6a43b6|CM14 4NA        |CM144NA               |true                  |
# |3742b35d-1fe2-4334-8341-eb5b4b725e65|f58e2a1a-f916-41a7-a463-0a06a907a3ab|NR13 6BA        |NR136BA               |true                  |
# |53353dd7-9811-4630-bdd8-2ceb88969709|09f98d83-2bc5-4c1d-9dc0-02992a8b42b9|EX13 5AF        |EX135AF               |true                  |
# |851dd272-fca3-4f0b-abc6-a10900aa0f24|7c68afee-9f31-473d-a11f-604d118a21e4|CV7 9DA         |CV79DA                |true                  |
# |17c4d76c-ef5d-42ef-8abe-cdf782161320|171d0ff1-292e-4730-aaca-fe83b5c57dd0|TA18 7AF        |TA187AF               |true                  |
# |0b709c17-b0a2-4b3e-98fa-a64a85f0999f|ed16f2db-cd29-4944-8357-f029bda1938b|GL53 9ER        |GL539ER               |true                  |
# |fdc79291-325f-4a69-91ca-3b3b0a5330eb|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|HD9 4AG         |HD94AG                |true                  |
# |f6279a26-a370-4918-a00f-7bf300bf5f08|4d3a4fea-42ac-4174-92b1-1699c6504298|TN35 5NB        |TN355NB               |true                  |
# |4ead0137-1699-461f-9088-f6e4658da804|6f985cf6-5ae3-428b-b56a-a36f39f59c68|M34 5GB         |M345GB                |true                  |
# |2ce8ff8b-1c12-49c2-b4ed-7249eb496398|ed16f2db-cd29-4944-8357-f029bda1938b|NG25 0TX        |NG250TX               |true                  |
# |9f1ef16b-a564-429c-aae6-8aff22827f6e|8a02ddc6-2f42-4848-8540-a7c183f0983b|BN15 8RB        |BN158RB               |true                  |
# |ab2f585a-e1ee-4fdd-b186-7ab59bc87b48|6a8376c6-0503-4a13-abc4-22b9c1af9d06|TN23 5LB        |TN235LB               |true                  |
# |8f8f48e8-03d4-4e75-9b1b-196e06d1736b|89c9b63d-ebbe-4b77-88a8-086a55d8a50d|IP28 6LF        |IP286LF               |true                  |
# |d848836e-4633-46eb-8923-7588499f4835|ff8955c0-59f0-4161-aa4a-ca114fa01238|NG17 2AH        |NG172AH               |true                  |
# |3e0c2484-ee61-41ab-abe3-9a956ece4c44|6dfda7a6-b9dd-4b44-b17a-2be15e8e984f|PR7 4AZ         |PR74AZ                |true                  |
# |a67dc79b-3648-41ad-8838-9a3111927666|01b4acb5-528f-4da9-a58f-eb71eb04e386|RM7 9BQ         |RM79BQ                |true                  |
# |99a764bb-4fbb-437f-bfd1-c437d86a192b|e86849c8-d3a9-48ca-852a-cbbfa589155b|IP25 7AQ        |IP257AQ               |true                  |
# |1dce11f6-d7bb-448f-b124-8aa904451e9d|0131c8ce-6d0b-4888-a420-5adf3e08990f|BH25 5PR        |BH255PR               |true                  |
# |6a34ac56-c10a-4aa5-b33b-1c8c1ae300d0|2feff59d-ca15-49a0-9100-165cded25a37|WD17 4QY        |WD174QY               |true                  |
# |32d61069-23b6-46b8-86eb-7573b1234858|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|SK5 8HT         |SK58HT                |true                  |
# |8e42a3f4-8ac2-4c4a-8b18-07b7c80bf8c4|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|S40 3BQ         |S403BQ                |true                  |
# |9ac6ff21-dcd3-4480-baa0-f4dd9e22d9e2|318eddb1-dcf8-4a7f-b6e9-781100f3dd96|FY4 2HE         |FY42HE                |true                  |
# |7541b5de-98b8-4e2c-85be-7d1e632112d1|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|LE7 7NL         |LE77NL                |true                  |
# |ff58aceb-a517-4281-bba7-979eadc7d59d|9b2e5984-a581-4a3a-accf-66c61c1454a1|CT3 2HN         |CT32HN                |true                  |
# |666cc3bc-9766-48b2-bedd-8e08457ba8ba|1053f381-72ca-4e62-b9e8-3efde62b0da3|NK              |NK                    |false                 |
# |d828dfb3-16af-489a-a1e8-ce87e3d72869|59e6a743-4540-412c-862d-7c2c0d150ec7| CB22 5JU       |CB225JU               |true                  |
# |50d1b731-247b-4697-ac97-d337be827f2d|9a134f5a-3d54-4bff-83c9-54a688061f31|TQ12 3DZ        |TQ123DZ               |true                  |
# |3d0f146c-a00f-4805-a477-18faea199a53|cf60b4e0-00c4-4b5c-a86e-a93764d1e01d|DE56 0QW        |DE560QW               |true                  |
# |89749400-0f35-4883-a6af-03598c471a81|26448b3a-72f0-4d2f-976e-85793dcdb7fd|SW11 4DS        |SW114DS               |true                  |
# |1456511a-d2d3-468f-a495-96835d7b915f|ac5d475e-0f23-4ea7-87ae-a67bbbc4e8fd|KY12 0AB        |KY120AB               |true                  |
# |9d6791a8-7be7-4511-b67a-4d01e93da283|d1b182fc-523f-48fa-825e-512c19b5df70|EH16 5LP        |EH165LP               |true                  |
# |2b6ce59e-ddac-478c-8e50-e9a4a2a78a03|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|S44 6XP         |S446XP                |true                  |
# |dfed7629-6f36-4817-8941-65b1651cbfcd|07b2aafe-cb44-44a5-add9-29eb579f8a73|BT80 8EH        |BT808EH               |true                  |
# |ea9ef77d-b959-4297-82ea-970cd1627718|18c6698a-b3f4-4aa6-96e9-f5a08015e275|NW5 2PW         |NW52PW                |true                  |
# |21c98728-08f2-472b-aad9-c34c34d472f3|a97c8f2b-4ba3-4b18-b77b-dce09488ed4e|HU5 4DT         |HU54DT                |true                  |
# |0a3f39ed-791c-44fd-a464-526eae9c5d7c|59ccb050-9c99-4914-b62b-be2d1fbbd84e|CT18 7SS        |CT187SS               |true                  |
# |c657aae7-a87c-4c75-abca-14a230d58476|9fa341d5-64c2-426a-b797-02f8f7e4fcb7|DN37 7AH        |DN377AH               |true                  |
# |0a14ee0c-b998-46d7-a252-fff80125bcba|18c6698a-b3f4-4aa6-96e9-f5a08015e275|RG45 6ND        |RG456ND               |true                  |
# |368cc639-8719-4445-a142-d223228f4fdf|f56db364-2814-43b2-b049-62edcbd20912|B60 1BJ         |B601BJ                |true                  |
# |1c2c859b-54cc-4995-9992-3b465db5cc8f|f56db364-2814-43b2-b049-62edcbd20912|SO31 5DR        |SO315DR               |true                  |
# |ef9e33b3-c567-4f0e-bb6a-64811dfe3a86|2e60761c-14a1-45b0-8b77-123c8f671947|PL12 4BY        |PL124BY               |true                  |
# |b2159b2f-7ca8-41d7-bbf1-875a88837c36|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|PR1 9HL         |PR19HL                |true                  |
# |70d062d9-3b1c-40d8-8fd4-be09bbfc2c4c|e3805d41-51d0-4277-8375-f3c1b8899b43|ML2 9QW         |ML29QW                |true                  |
# |33ed961e-5b4d-4889-a5f4-f59ff56c8d02|1a28f7e9-3332-4d1b-af07-c36175d656d1|TA1 3JH         |TA13JH                |true                  |
# |97e8e4db-a016-47aa-8973-2a9b65b3481d|3fd81815-2475-42e5-9b4e-c834175632b4|HU16 4DD        |HU164DD               |true                  |
# |5a2a171b-f803-4807-ad72-0a1df0fbf191|fe38979b-0ec8-4962-92d1-db1e9857b25f|OL11 6QE        |OL116QE               |true                  |
# |d1ad0bed-8601-4676-9da1-c04759b0ede7|01b4acb5-528f-4da9-a58f-eb71eb04e386|BN22 9PR        |BN229PR               |true                  |
# |4db44a22-b8f4-4d48-b32a-784f1290eaaa|86174553-4ff3-4687-922b-04b3a27d1454|TQ1 2EA         |TQ12EA                |true                  |
# |192c09b1-98cd-4416-94f7-d9d607991e6d|08faa230-0f44-498a-aa0a-b9cc3fa5733c|TQ1 3NW         |TQ13NW                |true                  |
# |0890cfb0-0338-444b-9422-44bfabf9ef58|0def29cb-7177-4562-8e3d-e64476273ca8|S7 1LW          |S71LW                 |true                  |
# |562999ed-ebe4-4e82-86ae-96edaa3666c9|12ef3fb1-52dd-42d8-948b-e007c73e78e8|DE4 2JW         |DE42JW                |true                  |
# |99df1184-aaee-49bd-af1a-6249da3e5f00|afcc2f69-e61a-46e4-8560-3f57cab67010|PH2 6AT         |PH26AT                |true                  |
# |5f82f853-d38f-4276-ba65-0643e336f38b|c08b7f52-8981-48c7-bfdc-8a704978bb8f|DA15 7HJ        |DA157HJ               |true                  |
# |618ff13a-7999-484c-aeab-adefc37b331d|07b2aafe-cb44-44a5-add9-29eb579f8a73|CV11 4QJ        |CV114QJ               |true                  |
# |36642f88-3dc0-4f9f-8adc-8c48f70e9e0c|7c68afee-9f31-473d-a11f-604d118a21e4|CV31 1PB        |CV311PB               |true                  |
# |9cc95103-8ab1-484a-8da0-b5d712e3d6fd|ed16f2db-cd29-4944-8357-f029bda1938b|LS9 7PY         |LS97PY                |true                  |
# |9336b1d6-60ee-4404-ad47-4ebc2dd71c92|ac62dd7c-eb46-4922-84cd-2f4b1d231280|SK3 8HT         |SK38HT                |true                  |
# |41c4f576-7377-4763-8258-ac56262e555b|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|NG5 7GS         |NG57GS                |true                  |
# |65c7079c-64d0-4b74-942a-485f64e19f1d|f56db364-2814-43b2-b049-62edcbd20912|TW20 9AD        |TW209AD               |true                  |
# |da61e2e0-72e3-4ced-a57b-374625cc6c9b|01b4acb5-528f-4da9-a58f-eb71eb04e386|E4 6NF          |E46NF                 |true                  |
# |a6b56fb5-e46d-496a-8b3c-7adcad6d1f99|220792aa-62b3-4053-a8e2-862a18be2450|EX7 9DS         |EX79DS                |true                  |
# |1f9c34f0-527b-4efb-b67e-c4515b68db25|de4d57cd-a7fc-47db-9f9b-7e8e736dac20|OX27 7NZ        |OX277NZ               |true                  |
# |d5a06138-aa2c-42b8-a255-6b6e38094dd8|4a2413b6-7673-4a18-824e-9d1c1c1bc894|EX39 3QB        |EX393QB               |true                  |
# |7775cc54-846d-4518-b676-f5c7edb0544f|99b10abb-dcee-4b52-a63c-5852cce8edd3|B97 6AT         |B976AT                |true                  |
# |a16f1c1c-8775-46c8-8b7f-37648e947c98|ac5d475e-0f23-4ea7-87ae-a67bbbc4e8fd|DG9 7QL         |DG97QL                |true                  |
# |bf9e4511-3726-48ed-9e16-57fabee52f36|fba55514-83b2-4f12-a2e0-d2a98603c3a1|HA5 2NB         |HA52NB                |true                  |
# |7a704aeb-0a34-4cb8-b7e8-7ec2a1a61511|bdbc4693-4d98-4d96-b9a3-4dc0162818f4|DY3 4AE         |DY34AE                |true                  |
# |4a7502f0-3725-48d7-827c-2819de038044|07b2aafe-cb44-44a5-add9-29eb579f8a73|SS11 7HR        |SS117HR               |true                  |
# |b04a3f31-f75a-4bab-93e0-d8b7bb1f654c|ac62dd7c-eb46-4922-84cd-2f4b1d231280|SK1 4AU         |SK14AU                |true                  |
# |26205244-e37d-411f-995b-86bc75d47c38|f58d948b-f4a9-4536-a8c5-a983fc2d36c2|SO30 4EB        |SO304EB               |true                  |
# |8121f9ce-4a1e-4250-97fb-031d2ab37326|ac5d475e-0f23-4ea7-87ae-a67bbbc4e8fd|S63 9PY         |S639PY                |true                  |
# |c05eea24-9434-48ae-970a-5ac9fc9057af|8c9d6157-abef-4a16-a00b-a086b5c6776b|CT6 7ES         |CT67ES                |true                  |
# |57feb51d-4878-44b5-b204-3372cda7c996|a9b3a258-9555-4591-bce4-28e490705e88|TQ3 2RL         |TQ32RL                |true                  |
# |987b870d-6327-4c19-94d7-79509f061770|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|L35 8NB         |L358NB                |true                  |
# |0fd517c6-529e-4736-814f-5affbf0b0881|e2b2cac7-5edd-428a-b892-8f510c6a43b6|WD25 8HA        |WD258HA               |true                  |
# |5fa5a508-baa4-415c-97c8-6970c0542881|01b4acb5-528f-4da9-a58f-eb71eb04e386|TW12 2DW        |TW122DW               |true                  |
# |42e4374d-9182-4bf6-977c-fdc3c583fc18|7c68afee-9f31-473d-a11f-604d118a21e4|CV34 5SP        |CV345SP               |true                  |
# |31f33265-fece-4bab-a53b-28333db11999|2feff59d-ca15-49a0-9100-165cded25a37|AL4 9DQ         |AL49DQ                |true                  |
# |9821101a-3211-442d-892c-90e8fcd4a706|6c69d134-b943-4786-b8f0-b197437aa946|DG11 3AU        |DG113AU               |true                  |
# |2974bd3f-5860-46c5-b3f7-af7f59c07d36|5dab7dbe-7983-40cb-9ec5-b57ced568fac|RH3 7DR         |RH37DR                |true                  |
# |962b97a7-d73e-4cc9-9645-06545d7f9060|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|SR3 3DJ         |SR33DJ                |true                  |
# |af08a483-dca0-4e09-b183-9860c4d33a92|144c3c08-3ada-4913-8520-5b60d545e60a|S9 4JQ          |S94JQ                 |true                  |
# |c86b70e4-b919-443b-8483-53e916b5601d|07b2aafe-cb44-44a5-add9-29eb579f8a73|LU3 2TF         |LU32TF                |true                  |
# |bc0543ff-8d1f-4742-b4e7-d2042a41ccbe|fd90d8eb-b012-411e-b6cc-209d505493ca|MK40 2NT        |MK402NT               |true                  |
# |7e67e5d0-3243-4978-9040-405b4e72a8a9|7a36fb96-ccde-496d-9214-2d89d1c74b4b|BD9 4DW         |BD94DW                |true                  |
# |beb47811-9ac0-4796-9d8f-f418017dd4fc|23c4b2a1-22ca-4393-9f89-0c900bcb4bd5|LE9 7DG         |LE97DG                |true                  |
# |e4b68000-d5d1-4917-b1ad-b58afebadf1c|13df52eb-c61d-48c9-968f-b99845c11fe5|PH26 3JQ        |PH263JQ               |true                  |
# |c0259ee8-e9e1-48b1-86d3-af25544c5a19|c94e6850-c754-473e-985a-29169d71b602|KT2 7LX         |KT27LX                |true                  |
# |09698ea8-9d40-4aee-8608-b9b07b39ae1e|ed16f2db-cd29-4944-8357-f029bda1938b|WF12 8NJ        |WF128NJ               |true                  |
# |386235b6-54c5-407e-916a-935c08ecce65|07b2aafe-cb44-44a5-add9-29eb579f8a73|CO3 0PG         |CO30PG                |true                  |
# |6ed76cde-950d-4d7c-9992-160356c14f88|e2b2cac7-5edd-428a-b892-8f510c6a43b6|SG13 8EG        |SG138EG               |true                  |
# |286abfc5-49d5-4ed7-ba31-8e741426d7ca|e2b2cac7-5edd-428a-b892-8f510c6a43b6|KT18 5XA        |KT185XA               |true                  |
# |49203fe7-0ff6-4b30-8c57-0cd5324ae133|c931ea83-7b27-4812-94b1-fd327b05c8e7|SE6 3AU         |SE63AU                |true                  |
# |8bdad56e-ce03-4ebd-a538-d69b5c138bfd|286f281e-f48b-4b88-a948-60bf9d9d35aa|WF12 0JZ        |WF120JZ               |true                  |
# |9280249d-cabe-43b4-8c30-46643d4142a7|f63863e6-e15a-4d7c-bd2e-c05369d5bac7|CH2 1LY         |CH21LY                |true                  |
# |3ba94f91-df8c-431a-b4ba-3aea00801056|48638a08-459f-4d54-80f5-5b6b49debb5f|M40 1QQ         |M401QQ                |true                  |
# |691d6f03-2d41-4a88-b74d-9e1b5322681e|7162ff50-b7bf-4819-9065-0d1cf02a03c0|FY7 8RW         |FY78RW                |true                  |
# |1a7fdd42-dec4-4669-bce4-5ff30efb6968|3344e559-2b16-4f71-816b-a48fd5a4b3c2|LE3 3PF         |LE33PF                |true                  |
# |c0a86627-d5a1-4b51-85c6-ff031d122dc3|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|WA5 3JS         |WA53JS                |true                  |
# |50f64f12-643c-4c2f-9675-3464254123ec|a97c8f2b-4ba3-4b18-b77b-dce09488ed4e|DL9 4LJ         |DL94LJ                |true                  |
# |03ae6965-6f0e-4feb-89f1-e416cd1562d1|1e345e0f-3bf5-4a0f-9752-f220f8125da4|RH16 3EG        |RH163EG               |true                  |
# |c0f53855-aaa8-4bca-a5be-d861afcbb2b9|051f4538-5908-4683-9f77-73067ffb3b6d|B24 0BE         |B240BE                |true                  |
# |0992588e-87cb-447e-b102-2acda29417cf|b3eb0b85-03d2-451b-b22d-0f2837711161|ME12 3PX        |ME123PX               |true                  |
# |982ecda4-5790-4e01-af21-a1b5d8cab794|17e082ae-7f8b-4b9b-a0ef-d6a62642acfb|NR9 5AY         |NR95AY                |true                  |
# |6a3911db-58c0-422d-bc0b-7ca0b190ed02|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|NG20 8BS        |NG208BS               |true                  |
# |d46034f2-b1f0-4bbe-9c96-f7e73031b3aa|07b2aafe-cb44-44a5-add9-29eb579f8a73|BT74 4BB        |BT744BB               |true                  |
# |eabd8482-408a-4cc7-b8d6-9ec49983c569|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|WA9 5EL         |WA95EL                |true                  |
# |9245d3e8-0fa7-4ff6-af59-3e14c1099ad0|59b99769-cc23-4065-9b8a-a1e6d446d282|PO10 7QR        |PO107QR               |true                  |
# |d27f4927-59d7-47d5-9f5c-c2e3ac9c1eb9|01b4acb5-528f-4da9-a58f-eb71eb04e386|TN1 2ED         |TN12ED                |true                  |
# |d53a8f31-24c7-4348-8bd9-9f2a490c99f5|b25928b4-8cc7-41ce-bc10-b489c3b73b30|IG10 4NX        |IG104NX               |true                  |
# |f0cf1df0-9b06-4cbc-94f8-b7632d57d51e|ed16f2db-cd29-4944-8357-f029bda1938b|HX1 4JW         |HX14JW                |true                  |
# |ef0621e3-9602-4fb9-9a5f-5e56f369d618|2c641569-c1a2-4b5b-b17a-f786c1c1672c|MK40 2PU        |MK402PU               |true                  |
# |183412a9-aff5-494a-b2e9-8a9c3ad7bcc1|63ce92a1-c01a-4cad-8036-63f42c353715|LU3 2BB         |LU32BB                |true                  |
# |8a7e3c00-0d2f-4e88-b25b-fbbf249b1f6c|fd5b4db0-7e3d-4065-854f-c311c19f6eab|SO23 9LN        |SO239LN               |true                  |
# |5ba0d45f-3d6b-4790-bbd2-0d0309d42178|144c3c08-3ada-4913-8520-5b60d545e60a|S60 5QS         |S605QS                |true                  |
# |cb69b523-e8b1-49c8-a1a2-1070d8acb17a|ca4daf40-c6eb-4ec3-be6e-0f108942dc64|NR33 0LQ        |NR330LQ               |true                  |
# |f89c6a2c-a6f8-41b1-8877-aa93e2cd0661|43ae1eca-1304-4f6d-bc01-e7583212644c|LU6 3SD         |LU63SD                |true                  |
# |cb695666-2846-4e05-99cd-8cb20584d359|ca4daf40-c6eb-4ec3-be6e-0f108942dc64|PE38 9PA        |PE389PA               |true                  |
# |742d326c-bf72-4f88-9961-e6cddf38f570|e3805d41-51d0-4277-8375-f3c1b8899b43|ML5 5NJ         |ML55NJ                |true                  |
# |9f72c93d-7047-4cbc-88b0-7d3c07ff1ba2|14c6aee9-5edb-46d3-a370-5ea7e15351eb|YO26 8BT        |YO268BT               |true                  |
# |4478fac0-3342-4d4e-8d7f-93d8633d966e|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|LS22 7DS        |LS227DS               |true                  |
# |d2e933a5-75b8-4bb6-92fc-51790bd51eca|1ce12b55-7819-4339-a0a0-a227cc831cab|NN155PA         |NN155PA               |true                  |
# |3b27867a-7f5f-437b-8b04-173f1b84079f|1f880809-2d39-419d-9205-9d0830a71a3e|BD3 8DR         |BD38DR                |true                  |
# |6b40a920-c975-4afd-be52-0bee45f00ef1|2feff59d-ca15-49a0-9100-165cded25a37|SG4 9AL         |SG49AL                |true                  |
# |93f89ade-a281-4984-8def-9e922cf3725f|e2b2cac7-5edd-428a-b892-8f510c6a43b6|KT2 7EQ         |KT27EQ                |true                  |
# |72a9c568-f320-42ef-b541-8e3d08804c91|ac5d475e-0f23-4ea7-87ae-a67bbbc4e8fd|EH46 7BD        |EH467BD               |true                  |
# |c9c82d64-cb73-44db-a5d4-db423fe34a14|4cc2c167-98fa-439b-a276-a4dc4ee81fd4|YO31 8TA        |YO318TA               |true                  |
# |695c9363-3f2c-4fc0-bcd3-83e14bb5bfc9|f56db364-2814-43b2-b049-62edcbd20912|PO7 7TY         |PO77TY                |true                  |
# |02d5665c-fdd7-4c41-bfac-96502c0e07e5|6f657107-1693-47b3-8309-9e17fa6461af|WR10 2LA        |WR102LA               |true                  |
# |037aeded-bd82-4b6f-91d6-1bdd625b5676|4cc2c167-98fa-439b-a276-a4dc4ee81fd4|RH4 1SY         |RH41SY                |true                  |
# |2310c478-c9c1-4c00-8943-794ea69fe5e1|8e51bb0d-d212-47e1-8b8b-eb8891380bff|CT8 8JJ         |CT88JJ                |true                  |
# |fe0abe2c-b64e-4f45-8000-75219beaf5cf|bb688cfe-0111-43e0-9180-d1a47e1d60b8|IP11 0SY        |IP110SY               |true                  |
# |003fc55e-b9af-4b28-a0bb-65acd92370f2|a3fbd3a7-481e-460d-80d3-58f1d010620e|M20 2YW         |M202YW                |true                  |
# |9eb3e14b-0e92-46e9-a6fc-ad818214a433|9b939a1e-0462-47c4-8f2f-89f396e12e58|DN2 6BL         |DN26BL                |true                  |
# |84fdd714-efae-4a60-8c9c-ec006c14d298|2288b9c1-16ef-402d-8395-f2c1f62b15f3|DL159SY         |DL159SY               |true                  |
# |258a9319-87e4-44f4-b954-09c2ec695738|a3fbd3a7-481e-460d-80d3-58f1d010620e|ST5 2RS         |ST52RS                |true                  |
# |73e3afec-a2de-4916-a1a3-0d723ae5ed34|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|SR3 3DJ         |SR33DJ                |true                  |
# |0307c01b-70db-48aa-824f-7823c464d8f9|18c6698a-b3f4-4aa6-96e9-f5a08015e275|WD6 1EP         |WD61EP                |true                  |
# |819a0f5e-c1d4-4c7d-a55e-886ea9243315|034a4560-de6d-46fe-9cfc-978cfdc9c431|PR4 5ZJ         |PR45ZJ                |true                  |
# |c63e785d-1957-493e-9d23-3f4e5b877bfe|f828d521-dba4-4a94-8720-3fd69fa9d1d1|RM18 7QJ        |RM187QJ               |true                  |
# |cd8c9899-3017-48c9-b0f4-cb68a462e6ec|a9d6c8ca-4803-4868-9f10-1aef05c0ae4d|ME14 4HN        |ME144HN               |true                  |
# |b57709b5-ea35-41cd-a47f-b48847c25d53|419a562e-a61b-4a1c-b8d3-332e59e23e18|ST4 6QZ         |ST46QZ                |true                  |
# |f3f701e0-dd7f-4d2f-a441-86b16383dbcf|17e082ae-7f8b-4b9b-a0ef-d6a62642acfb|NR17 2AS        |NR172AS               |true                  |
# |d303fd4e-f829-4200-b6a2-1cafef85650c|8f8ebcbb-d282-4e2a-bf1c-12051e8de0cb|KA21 5DB        |KA215DB               |true                  |
# |9664f234-2dc3-47bc-9ab3-9eac6aaadecb|ed16f2db-cd29-4944-8357-f029bda1938b|UB4 8DU         |UB48DU                |true                  |
# |a3862a7c-a39c-45b8-b9f1-484538c4449d|9182fbe7-c12f-4156-bf59-89ecffa821d2|CO4 3BS         |CO43BS                |true                  |
# |dca7f2eb-7f92-4e29-9070-d732afe64c9d|cf60b4e0-00c4-4b5c-a86e-a93764d1e01d|NG15 7JD        |NG157JD               |true                  |
# |ed014cc0-8d0d-4338-a5e0-729594283b34|ca7900ac-09e6-452d-a21c-ad99361e1912|WR13 6LY        |WR136LY               |true                  |
# |17691e7d-f572-4fca-8fd0-3bdf0a916ad2|a6e3b390-2e1e-4203-a0a8-973f9221b408|PR1 6AB         |PR16AB                |true                  |
# |cd435da9-511b-4444-aa69-5b0229a59c8b|5af0dd81-cc55-4a6a-baf0-b4b9b2c5f983|WS8 6AN         |WS86AN                |true                  |
# |31f1a0c0-0085-4231-894d-3af26c6d0d3c|318eddb1-dcf8-4a7f-b6e9-781100f3dd96|PR8 2BP         |PR82BP                |true                  |
# |5cfc19ce-2756-4606-9dc5-8383efcb8c59|65666a5a-c97a-4f8e-aac7-5a6d2535efce|SA18 2HW        |SA182HW               |true                  |
# |9f9d9ddf-cbd0-4f6b-86f5-560775369264|5918c36f-fb48-490a-9c6b-0f64a0670681|L4 8UD          |L48UD                 |true                  |
# |4e122355-9eea-4405-8a0a-2903464bc5b2|332b86c9-cb30-4500-81d4-86abfec2f980|BS20 7QA        |BS207QA               |true                  |
# |a3610a5a-5dbf-43a7-93dd-f911819ec121|07b2aafe-cb44-44a5-add9-29eb579f8a73|SS6 8FE         |SS68FE                |true                  |
# |8b1ce48c-001d-4d55-ad75-c7182e53cb9d|8cca22ff-eeb0-4079-af4b-92cb07ef4c15|B32 3BA         |B323BA                |true                  |
# |12c3586b-1df4-489d-ac4c-30356d2e529d|e83e1a50-031f-4eae-b615-5748dead6d66|BH14 8LH        |BH148LH               |true                  |
# |729b04f5-3d08-48d7-a3a8-159d2288fec8|ecbc4302-2287-4ca2-bfce-ad28c5da45e9|PO5 1NF         |PO51NF                |true                  |
# |8219c543-b520-486e-bf16-cfd28a3cee98|09f98d83-2bc5-4c1d-9dc0-02992a8b42b9|EX12 2PR        |EX122PR               |true                  |
# |31b3b770-dc91-48a7-92b8-b144f74d86f8|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|WS12 3HR        |WS123HR               |true                  |
# |543b93db-535d-4bb6-9eba-7f73b2dea0fd|f56db364-2814-43b2-b049-62edcbd20912|SO51 0BL        |SO510BL               |true                  |
# |563e73a7-cc3c-4c8f-aefe-94cdc9c2e33c|26058464-ff9c-4708-9746-1e8c6adc9140|RG23 7EL        |RG237EL               |true                  |
# |ed30333a-5c8e-44e0-b87e-fe0024ad8ef8|e0c5beb7-c304-4890-9878-4814e116fb02|NE22 5TT        |NE225TT               |true                  |
# |629f04f2-b5b8-4fa2-a197-2d95301d15bf|c94e6850-c754-473e-985a-29169d71b602|CR6 9PE         |CR69PE                |true                  |
# |971e51b5-12ee-4e10-b671-dcca7599bcb6|1090b639-33e4-4865-bad1-9032c25426ae|EX11 1RH        |EX111RH               |true                  |
# |cc8d9399-1adc-4b34-9983-37cc328e0987|aa532354-1e4d-40d5-b493-3bc939b58cfa|YO15 2LX        |YO152LX               |true                  |
# |2cc8bea8-d966-4f96-8431-8b5201d56809|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|YO26 6RB        |YO266RB               |true                  |
# |b84a2125-3a16-47a0-89fc-b527816f4bde|cf60b4e0-00c4-4b5c-a86e-a93764d1e01d|DE55 7JL        |DE557JL               |true                  |
# |a11f7f8b-341b-4cb6-9762-f6701869bee5|ac62dd7c-eb46-4922-84cd-2f4b1d231280|SK3 8TB         |SK38TB                |true                  |
# |f27d762b-9725-4103-8655-dafe521e9a03|2feff59d-ca15-49a0-9100-165cded25a37|WD4 8AA         |WD48AA                |true                  |
# |593d7630-ae15-4fb9-b1a0-0eb013fe98c9|2feff59d-ca15-49a0-9100-165cded25a37|HP9 2TN         |HP92TN                |true                  |
# |ba444572-9ea9-4047-a856-80d0ed6a8cdb|f63863e6-e15a-4d7c-bd2e-c05369d5bac7|FY6 0AH         |FY60AH                |true                  |
# |3a511fbc-e91e-4808-81ff-63dd7d4d49ed|72c3177e-9fa0-4fa3-a7a6-1bfce447a580|EH5 3JW         |EH53JW                |true                  |
# |61d4a090-9f15-4525-8f69-dc104f7c6b85|ae6143b2-9e68-4b6e-abfe-e4701c064dfa|SO16 7DD        |SO167DD               |true                  |
# |ca100f73-2614-4611-91f9-8996bb9ae0ec|1222392f-cdda-4d53-add3-4d0b774653ae|B44 8BW         |B448BW                |true                  |
# |875316f0-4807-4409-890e-f63ed08defeb|afcc2f69-e61a-46e4-8560-3f57cab67010|KY8 3DE         |KY83DE                |true                  |
# |3796c06d-04b2-4666-9ef0-439a7c7ffa53|afcc2f69-e61a-46e4-8560-3f57cab67010|DD46JU          |DD46JU                |true                  |
# |86a62976-89a4-4721-8a2a-a92d0f1d7f82|e8bea274-a2a9-47ac-ac44-c675f8af99d9|NR35 2PE        |NR352PE               |true                  |
# |55c946c9-8d74-4564-aa82-d9f58781ff47|593f84d4-f5a9-4a1e-bacd-2e36bba51072|LE9 6QF         |LE96QF                |true                  |
# |4dcdb5b6-f500-4638-961e-bd95421b3a3e|593f84d4-f5a9-4a1e-bacd-2e36bba51072|LE9 4FG         |LE94FG                |true                  |
# |9930ceeb-0d96-47d7-831f-4267442be4d5|3d399980-1b8c-4140-b117-7f1eaf25c1ef|PE14 9RQ        |PE149RQ               |true                  |
# |f12d56c6-17f9-4ff7-8083-a41d691d7d30|f8a8fc9d-537b-4fc0-9102-9eac4dae538f|EX39 3PA        |EX393PA               |true                  |
# |c343facb-ba0d-4b4e-ab95-891f8bb6c5bf|a84fce5a-38c5-4c64-ac33-7284f20f158d|EX8 3DX         |EX83DX                |true                  |
# |e6c5d219-d8f2-4d17-9fb0-b0a522caedf5|c49548f7-c55f-4069-8641-4c5ff80149e2|EX39 3PT        |EX393PT               |true                  |
# |425ef4cc-0777-46b4-adde-a790a9d7900f|e05f6a30-9d41-4562-82ea-af86aa0c9a1f|RM14 3PL        |RM143PL               |true                  |
# |cb9e50ab-bb1f-4cfa-8d7e-2f5a508d7b38|c82c1e64-55dd-46f6-bb09-f7a6ee13b7c6|YO11 1UB        |YO111UB               |true                  |
# |35d655fa-c9da-4c5d-97e0-1e1361ebf3ea|145cdd1b-b9c0-43f9-8394-7e5e32347a14|LA14 5LE        |LA145LE               |true                  |
# |ca57c766-05cf-4d9b-b2ff-d3f5758c382e|9e2f3e1c-412c-4056-ab4b-1d9a0412afaa|PL3 4SR         |PL34SR                |true                  |
# |da172bc1-507f-48bd-a4fb-3cd3ad627d2a|c3f208f7-52ba-4040-a4d0-3f63e24d4ffd|BN2 7BS         |BN27BS                |true                  |
# |8a30e105-6621-4e1e-840a-6dad56daff6d|084ab41b-53e7-42d5-9b5e-081f0102b3e6|S6 4TF          |S64TF                 |true                  |
# |3b67c8ca-bb42-4273-84cd-5fff10abdee1|1d8e8a92-09a2-4f99-85e8-687415c9fe00|KW10 6RH        |KW106RH               |true                  |
# |145154b4-01b4-47a0-ae20-2812dc8976e5|cc10c478-febc-4bbb-84e9-842621ce3ce8|WS10 8LE        |WS108LE               |true                  |
# |6565463b-9b2d-4d25-9567-285a846b0d7a|9a91c44b-03f1-44d7-9e32-e6f549f48f60|BD20 9JN        |BD209JN               |true                  |
# |e93d059d-52fd-4479-9416-0286f0952efe|30aa4a91-ff49-4b18-b6fc-7e2ec2887dce|CT14 9TF        |CT149TF               |true                  |
# |efbff726-8776-4e79-bc0e-e7a4a2569746|1ce12b55-7819-4339-a0a0-a227cc831cab|WD18 0JY        |WD180JY               |true                  |
# |d5581d76-3193-416e-bdc0-01978da16197|18c6698a-b3f4-4aa6-96e9-f5a08015e275|N7 7DL          |N77DL                 |true                  |
# |641af812-be27-4fd6-ab8e-29984ed6bb9a|034a4560-de6d-46fe-9cfc-978cfdc9c431|CA14 1SS        |CA141SS               |true                  |
# |97d91ef6-6329-4ba7-98a7-a35c0831f425|6fac1e19-0d6a-490a-85d7-247d799d46d2|B37 5PE         |B375PE                |true                  |
# |5462e7a6-2b26-4bf6-a7b1-61d57d093e1d|fd60e4f9-1d7e-475e-8ba5-2e2764f6a43a|WF14 8PW        |WF148PW               |true                  |
# |79270ff2-bd24-4541-99c9-6b44db041873|0552711b-d5c7-4421-8d02-a68caff862cc|PO6 1EE         |PO61EE                |true                  |
# |9afbaebf-076c-4f5e-b25e-aa07f3096862|7c68afee-9f31-473d-a11f-604d118a21e4|CV8 1HW         |CV81HW                |true                  |
# |95373681-1b3d-4085-9da2-df8d5dcb544e|4443bf3b-c6a1-4953-91d6-e607a63a2c69|TA20 2HN        |TA202HN               |true                  |
# |e52e1634-d171-4b9a-8d00-8aa5fdff33db|9955fbee-4168-4a1c-b4a6-dd9aeae04a85|AL6 9SN         |AL69SN                |true                  |
# |9320b250-e0ab-4fa0-8633-0a42a00e0c70|a2553459-1b96-4177-b8f7-bd41fb517507|CV2 5NY         |CV25NY                |true                  |
# |93d23938-1177-4e09-9784-a3df53217946|ca4daf40-c6eb-4ec3-be6e-0f108942dc64|IP21 4EE        |IP214EE               |true                  |
# |440b0765-8421-41b9-8d63-06fb74c53722|4b4e7cbd-7b9d-4e3f-bbfa-c699dc429774|PO12 3PR        |PO123PR               |true                  |
# |700c747f-4797-40d1-9cda-e788a48f348d|e2b2cac7-5edd-428a-b892-8f510c6a43b6|SL7 1HX         |SL71HX                |true                  |
# |1f68f1e2-379a-4cd4-b427-7f20eb250da7|0a237fe4-a126-4227-be13-ea49662ac865|TA6 3LS         |TA63LS                |true                  |
# |ea4eae65-e35d-4d00-af03-2fe61cf11484|e4a9e184-0903-4d2d-a1f9-a3429a9f93d9|TQ1 1QS         |TQ11QS                |true                  |
# |e27afb53-d3b0-4bad-b933-5ba241093a01|4a2413b6-7673-4a18-824e-9d1c1c1bc894|EX32 7EZ        |EX327EZ               |true                  |
# |887908a0-71be-467a-9d6f-e971547a0f0b|30e9b3ea-c37b-4939-8cb7-1c152677e1f5|E1 3DB          |E13DB                 |true                  |
# |70a0ff2e-7f19-4532-b107-947a76c46387|26058464-ff9c-4708-9746-1e8c6adc9140|GU16 9NP        |GU169NP               |true                  |
# |fec849e4-1034-4020-93d7-5bb46d01bfb8|9182fbe7-c12f-4156-bf59-89ecffa821d2|IP4 5HS         |IP45HS                |true                  |
# |7fee3dfb-01b1-4f1a-96fe-22c28006913f|70134ad2-f7f4-428a-96f5-71edf7b8382b|WR2 5SU         |WR25SU                |true                  |
# |5f16cfb3-7371-4a9f-91be-4c98ec8a2110|e8bea274-a2a9-47ac-ac44-c675f8af99d9|IP7 5QQ         |IP75QQ                |true                  |
# |fbb8155b-26ab-49da-a281-30f4906a2e9d|ea6ded20-1356-4cf1-9dc9-b1f1561cc5ae|RG1 5PF         |RG15PF                |true                  |
# |b42f119f-a3d1-42d3-a7f2-47b1d3539391|3c899f6d-776b-492d-b32e-083d044100b1|SO40 2RX        |SO402RX               |true                  |
# |73e95b06-0dad-46c0-a630-ffa6ef107364|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|NG21 9FL        |NG219FL               |true                  |
# |2813182d-edef-4468-b2e1-87942eb7ab2d|fe38979b-0ec8-4962-92d1-db1e9857b25f|PR9 9EB         |PR99EB                |true                  |
# |04edc7c7-e16f-496a-99b5-39ea2e8f21f6|61848498-2436-4700-b648-3cdc62747493|DL1 4UB         |DL14UB                |true                  |
# |a29f6155-28d4-4acf-93b2-2fbcee9f5387|d77edc54-3b9f-47de-8d5a-7f28224a1b53|BR1 3AS         |BR13AS                |true                  |
# |b36ad515-3d3e-4094-805e-19684e9944c0|0d3fe9a8-00e8-4965-9ad7-1cbd54562e76|TA20 1EZ        |TA201EZ               |true                  |
# |a7f59b23-c445-40f2-98ef-08c7c616b599|b69d7b9d-998e-4be2-a7d9-3c2809b8363b|YO7 1QH         |YO71QH                |true                  |
# |960cdf96-1531-462b-8c40-e43d23da85ff|a446b1c7-f180-4a99-8a2b-7cbbce1fabce|GL1 5JL         |GL15JL                |true                  |
# |9baa6b7e-d98f-4e25-92e9-2292557ce811|48638a08-459f-4d54-80f5-5b6b49debb5f|SK7 4RQ         |SK74RQ                |true                  |
# |85ae470d-1d6a-4007-8726-8c365fcef97f|59ccb050-9c99-4914-b62b-be2d1fbbd84e|TN26 3SN        |TN263SN               |true                  |
# |aa0c7a16-f1b8-4763-8927-5549752ac054|4b4e7cbd-7b9d-4e3f-bbfa-c699dc429774|PO16 8PT        |PO168PT               |true                  |
# |fdee235a-433d-4c3c-9c15-2678c141ac99|23cbd005-ee53-4634-bc9c-34495ae89667|NN15 7FF        |NN157FF               |true                  |
# |591a2b6b-1711-4086-9f7d-2bea7b8475d8|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|WA9 5EL         |WA95EL                |true                  |
# ...
# |9ba6c82a-7606-4e94-a5ad-fce2c844ff80|6e8fc945-c328-4a2f-a737-445d21fe5ae6|CB4 2HA         |CB42HA                |true                  |
# |5a08af25-1115-4570-88ae-9ba727239dc3|b65c9f9a-14fc-47e4-addd-8e0e3b12387b|RH19 2PF        |RH192PF               |true                  |
# |d40a77d7-bb9c-47cd-ada5-1cdfbdcc7382|6dfda7a6-b9dd-4b44-b17a-2be15e8e984f|BL0 0NP         |BL00NP                |true                  |
# |7c19a0c1-2b49-4ec3-89c3-e9967dede770|781772c6-8b67-4309-af9b-8f2215476558|NK              |NK                    |false                 |
# |6b333127-620f-4095-bd7d-db32f51013af|aeb5acfe-7c49-45c4-8825-f987a950f716|LE7 2AJ         |LE72AJ                |true                  |
# |774fe985-7989-460e-89b1-4db6b97e61d3|89c7fea2-ad47-40ec-8050-357f80b563e2|BN20 7QT        |BN207QT               |true                  |
# |86210488-3a0c-4464-88a3-4f46b5d6c53c|6d25fe7d-5e02-4ffd-b328-ee21522d4fff|NK              |NK                    |false                 |
# |fec1a1f2-bd60-4ee7-92e8-44116234273b|c92c166d-e4b1-4a38-8db1-9709bbd7a050|NK              |NK                    |false                 |
# |de49775f-3058-4513-96d6-399e1000e755|781772c6-8b67-4309-af9b-8f2215476558|NK              |NK                    |false                 |
# |70fc3b67-715c-477c-9177-dd30789a430c|1d8e8a92-09a2-4f99-85e8-687415c9fe00|KW14 7YL        |KW147YL               |true                  |
# |789c39d0-454c-4a98-9b1a-a1b3734faa9a|4c59ae4f-3668-4b19-bbb9-c9e54ce5d978|NK              |NK                    |false                 |
# |db8cb60c-ab36-4125-8ce3-9adf668a5a0e|181d26cd-e8f4-4750-a7bb-04eef2773c4a|NK              |NK                    |false                 |
# |074b1783-0f50-4ace-b107-cc799ea2551f|181d26cd-e8f4-4750-a7bb-04eef2773c4a|TEST 123        |TEST123               |true                  |
# |d97abb50-543b-4047-9a0e-f92cceec199e|781772c6-8b67-4309-af9b-8f2215476558|NK              |NK                    |false                 |
# |28571181-6e10-4486-96a6-6211f6a5366e|741fec62-7721-461d-949e-df6e509edec6|CM13 3BL        |CM133BL               |true                  |
# |8bdf45f4-c46f-46b2-9757-2a2903a84da0|4ec3aba3-dae9-4213-b430-483e0b7ae8c7|RG23 8HD        |RG238HD               |true                  |
# |febfb236-8be1-4611-a6a3-f6c69077b3dc|781772c6-8b67-4309-af9b-8f2215476558|NK              |NK                    |false                 |
# |c9a425e1-ef65-4a18-9a0d-34d1d6631475|4ec3aba3-dae9-4213-b430-483e0b7ae8c7|RG22 6PD        |RG226PD               |true                  |
# |006bf60e-dfd1-4b3b-9459-e6bcfd45eee2|781772c6-8b67-4309-af9b-8f2215476558|NK              |NK                    |false                 |
# |bce7a73c-7fb2-435c-979b-ec8ef7234dc0|32b025be-6f1b-4540-ad0a-c0dc146b9efa|PR26 7SG        |PR267SG               |true                  |
# |4d731caa-ed64-4780-b5cd-82b4897b5f47|3698d19a-7857-484c-bf3f-e621040fc8a4|B62 9HJ         |B629HJ                |true                  |
# |b6bc0ef4-0ade-4671-bd3b-f6c82a7cb6a7|59ccb050-9c99-4914-b62b-be2d1fbbd84e|BT42 4NR        |BT424NR               |true                  |
# |9129b996-9a91-45cd-8b79-28e6c27206d8|781772c6-8b67-4309-af9b-8f2215476558|NK              |NK                    |false                 |
# |057cff9e-97b4-4352-a2d8-b9621bf335ad|181d26cd-e8f4-4750-a7bb-04eef2773c4a|NK              |NK                    |false                 |
# |76d9f6e9-5c56-41b0-9d5f-b110856fc772|9f668474-ad5c-48dd-a5bc-049a11fafead|PL6 7JW         |PL67JW                |true                  |
# |128cfe0b-c0a9-4365-974f-c530a41d76b9|07b2aafe-cb44-44a5-add9-29eb579f8a73|SS7 2QL.        |SS72QL                |true                  |
# |68d94e86-5494-4011-864c-a2b60e9e30ad|afcc2f69-e61a-46e4-8560-3f57cab67010|PH1 1RA         |PH11RA                |true                  |
# |cbc1b281-2c0f-4261-aa41-7b8710c4dbc5|25a57c3e-8065-4e16-a6a9-aa8b5909f92c|SS0 8EP         |SS08EP                |true                  |
# |aab8fced-a0f1-4a3e-b58c-d62bc3c07790|9918bdbc-848c-4f14-9313-d6d556b29cb7|TD7 4DT         |TD74DT                |true                  |
# |3aaa7cf2-ac2d-4b76-a990-41fe8d65b5c2|781772c6-8b67-4309-af9b-8f2215476558|NK              |NK                    |false                 |
# |e19ac7ae-b9b5-4791-b24c-58788bd4647c|781772c6-8b67-4309-af9b-8f2215476558|NK              |NK                    |false                 |
# |7b09d6a0-ed3c-4a34-8fa6-618aee8a0022|bd6e72f9-37f3-47c5-96ec-e6a6f463132a|HG2 8RE         |HG28RE                |true                  |
# +------------------------------------+------------------------------------+----------------+----------------------+----------------------+
#
# +------------------------------------+------------------------------------+----------------+----------------------+----------------------+
# |LocationId                          |OrganisationID                      |LocationPostCode|LocationPostCode_clean|valid_LocationPostCode|
# +------------------------------------+------------------------------------+----------------+----------------------+----------------------+
# |666cc3bc-9766-48b2-bedd-8e08457ba8ba|1053f381-72ca-4e62-b9e8-3efde62b0da3|NK              |NK                    |false                 |
# |53f1a631-66f8-4137-b1c4-cb8b33e55e24|4c59ae4f-3668-4b19-bbb9-c9e54ce5d978|NK              |NK                    |false                 |
# |1d021111-bfe6-4454-b2ed-f344a4f392be|1dbcc944-63cb-4183-8783-f10af4510368|NK              |NK                    |false                 |
# |050eae2c-2e29-40c4-8c59-097bf393ac56|54f25f56-370c-442a-ac14-bc4f14fb2a44|NK              |NK                    |false                 |
# |0ec1b556-b6ce-4086-89f4-2fe46e28e477|781772c6-8b67-4309-af9b-8f2215476558|NK              |NK                    |false                 |
# |f8847f03-105b-40fc-b255-7a547e82033d|181d26cd-e8f4-4750-a7bb-04eef2773c4a|NK              |NK                    |false                 |
# |610935c7-389b-461b-b8f1-a65670b064e2|181d26cd-e8f4-4750-a7bb-04eef2773c4a|NK              |NK                    |false                 |
# |6b7aa6bf-e23c-437a-9d21-39a46198f115|4c59ae4f-3668-4b19-bbb9-c9e54ce5d978|HP5             |HP5                   |false                 |
# |eed5c183-d380-46e8-a488-47341601bf06|6d25fe7d-5e02-4ffd-b328-ee21522d4fff|NK              |NK                    |false                 |
# |e6e49c12-0b57-4d78-8037-4c46b1197dca|1053f381-72ca-4e62-b9e8-3efde62b0da3|NK              |NK                    |false                 |
# |5ff43c57-2617-4544-8ad2-0fc822fdad91|a6f3f04f-db77-41a7-a890-6a11604947b9|NK              |NK                    |false                 |
# |150a3112-b552-455f-b962-d7d6b420eb25|4c59ae4f-3668-4b19-bbb9-c9e54ce5d978|NK              |NK                    |false                 |
# |6b2eafd0-e0d0-496f-b19d-a54dae55c00f|781772c6-8b67-4309-af9b-8f2215476558|NK              |NK                    |false                 |
# |162896ea-1113-414a-972d-efcd3db1ec96|181d26cd-e8f4-4750-a7bb-04eef2773c4a|NK              |NK                    |false                 |
# |f882b236-5c8c-4864-ba66-72876ff19d25|181d26cd-e8f4-4750-a7bb-04eef2773c4a|NK              |NK                    |false                 |
# |82bffe7f-f8e9-410a-9dea-43e2d1f8c1f7|181d26cd-e8f4-4750-a7bb-04eef2773c4a|NK              |NK                    |false                 |
# |ea5b3b57-b377-4731-8a2c-7fa3148e5def|181d26cd-e8f4-4750-a7bb-04eef2773c4a|NK              |NK                    |false                 |
# |24ab5e43-c5b4-487c-b4a9-58c40b79cfdc|181d26cd-e8f4-4750-a7bb-04eef2773c4a|NK              |NK                    |false                 |
# |88fa984e-4e00-4554-980f-3cdc6034148c|181d26cd-e8f4-4750-a7bb-04eef2773c4a|NK              |NK                    |false                 |
# |9b1fe0b5-01c6-4f14-9383-feca2a84780e|781772c6-8b67-4309-af9b-8f2215476558|NK              |NK                    |false                 |
# +------------------------------------+------------------------------------+----------------+----------------------+----------------------+
# only showing top 20 rows
#
# +-------+--------+-------+------+------+--------+--------+--------+---------+-------+-------------------------------+---------+-------+------------------------------------+---------+--------+---------+--------+--------+---------------------------+---------+-------------+------+-----+-----------------------+----------+----------+
# |pcd7   |pcd8    |pcds   |dointr|doterm|usertype|oseast1m|osnrth1m|oa21cd   |oac11cd|oac11nm                        |wz11cd   |wzc11cd|wzc11nm                             |lsoa21cd |lsoa21nm|msoa21cd |msoa21nm|soac11cd|soac11nm                   |ladcd    |ladnm        |ladnmw|laccd|lacnm                  |pcds_clean|valid_pcds|
# +-------+--------+-------+------+------+--------+--------+--------+---------+-------+-------------------------------+---------+-------+------------------------------------+---------+--------+---------+--------+--------+---------------------------+---------+-------------+------+-----+-----------------------+----------+----------+
# |AB1 0AA|AB1  0AA|AB1 0AA|198001|199606|0       |385386  |801193  |S00090303|1C3    |Detached rural retirement      |S34002990|D1     |Non-metropolitan suburban areas     |S01006514|NULL    |S02001237|NULL    |8A      |Affluent communities       |S12000033|Aberdeen City|NULL  |2A1  |Larger Towns and Cities|AB10AA    |true      |
# |AB1 0AB|AB1  0AB|AB1 0AB|198001|199606|0       |385177  |801314  |S00090303|1C3    |Detached rural retirement      |S34002990|D1     |Non-metropolitan suburban areas     |S01006514|NULL    |S02001237|NULL    |8A      |Affluent communities       |S12000033|Aberdeen City|NULL  |2A1  |Larger Towns and Cities|AB10AB    |true      |
# |AB1 0AD|AB1  0AD|AB1 0AD|198001|199606|0       |385053  |801092  |S00090399|6A1    |Indian tech achievers          |S34003015|C1     |Teachers and carers in metro suburbs|S01006514|NULL    |S02001237|NULL    |8A      |Affluent communities       |S12000033|Aberdeen City|NULL  |2A1  |Larger Towns and Cities|AB10AD    |true      |
# |AB1 0AE|AB1  0AE|AB1 0AE|199402|199606|0       |384600  |799300  |S00091322|1A2    |Established farming communities|S34003292|F3     |Rural with mining or quarrying      |S01006853|NULL    |S02001296|NULL    |2B      |Prospering countryside life|S12000034|Aberdeenshire|NULL  |7A1  |Country Living         |AB10AE    |true      |
# |AB1 0AF|AB1  0AF|AB1 0AF|199012|199207|1       |384460  |800660  |S00090299|6A4    |Ageing in suburbia             |S34003015|C1     |Teachers and carers in metro suburbs|S01006511|NULL    |S02001236|NULL    |8B      |Ageing suburbanites        |S12000033|Aberdeen City|NULL  |2A1  |Larger Towns and Cities|AB10AF    |true      |
# +-------+--------+-------+------+------+--------+--------+--------+---------+-------+-------------------------------+---------+-------+------------------------------------+---------+--------+---------+--------+--------+---------------------------+---------+-------------+------+-----+-----------------------+----------+----------+
# only showing top 5 rows
# +----+----+----+------+------+--------+--------+--------+------+-------+-------+------+-------+-------+--------+--------+--------+--------+--------+--------+-----+-----+------+-----+-----+----------+----------+
# |pcd7|pcd8|pcds|dointr|doterm|usertype|oseast1m|osnrth1m|oa21cd|oac11cd|oac11nm|wz11cd|wzc11cd|wzc11nm|lsoa21cd|lsoa21nm|msoa21cd|msoa21nm|soac11cd|soac11nm|ladcd|ladnm|ladnmw|laccd|lacnm|pcds_clean|valid_pcds|
# +----+----+----+------+------+--------+--------+--------+------+-------+-------+------+-------+-------+--------+--------+--------+--------+--------+--------+-----+-----+------+-----+-----+----------+----------+
# +----+----+----+------+------+--------+--------+--------+------+-------+-------+------+-------+-------+--------+--------+--------+--------+--------+--------+-----+-----+------+-----+-----+----------+----------+
#
# +-------+--------+-------+------+------+--------+--------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+-------+-----+---------+---------+---------+----+---------+----+---------+----------+----------+
# |pcd    |pcd2    |pcds   |dointr|doterm|usertype|oseast1m|osnrth1m|osgrdind|oa21     |cty      |ced      |laua     |ward     |nhser    |ctry     |rgn      |pcon     |ttwa     |itl      |npark    |lsoa21   |msoa21   |wz11     |sicbl    |bua22    |ru11ind|oac11|lat      |long     |lep1     |lep2|pfa      |imd |icb      |pcds_clean|valid_pcds|
# +-------+--------+-------+------+------+--------+--------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+-------+-----+---------+---------+---------+----+---------+----+---------+----------+----------+
# |AB1 0AA|AB1  0AA|AB1 0AA|198001|199606|0       |385386  |801193  |1       |S00090303|S99999999|S99999999|S12000033|S13002843|S99999999|S92000003|S99999999|S14000002|S22000047|S30000026|S99999999|S01006514|S02001237|S34002990|S03000012|S99999999|3      |1C3  |57.101474|-2.242851|S99999999|NULL|S23000009|6715|S99999999|AB10AA    |true      |
# |AB1 0AB|AB1  0AB|AB1 0AB|198001|199606|0       |385177  |801314  |1       |S00090303|S99999999|S99999999|S12000033|S13002843|S99999999|S92000003|S99999999|S14000002|S22000047|S30000026|S99999999|S01006514|S02001237|S34002990|S03000012|S99999999|3      |1C3  |57.102554|-2.246308|S99999999|NULL|S23000009|6715|S99999999|AB10AB    |true      |
# |AB1 0AD|AB1  0AD|AB1 0AD|198001|199606|0       |385053  |801092  |1       |S00090399|S99999999|S99999999|S12000033|S13002843|S99999999|S92000003|S99999999|S14000002|S22000047|S30000026|S99999999|S01006514|S02001237|S34003015|S03000012|S99999999|3      |6A1  |57.100556|-2.248342|S99999999|NULL|S23000009|6715|S99999999|AB10AD    |true      |
# |AB1 0AE|AB1  0AE|AB1 0AE|199402|199606|0       |384600  |799300  |8       |S00091322|S99999999|S99999999|S12000034|S13002864|S99999999|S92000003|S99999999|S14000058|S22000047|S30000027|S99999999|S01006853|S02001296|S34003292|S03000013|S99999999|6      |1A2  |57.084444|-2.255708|S99999999|NULL|S23000009|5069|S99999999|AB10AE    |true      |
# |AB1 0AF|AB1  0AF|AB1 0AF|199012|199207|1       |384460  |800660  |8       |S00090299|S99999999|S99999999|S12000033|S13002843|S99999999|S92000003|S99999999|S14000002|S22000047|S30000026|S99999999|S01006511|S02001236|S34003015|S03000012|S99999999|3      |6A4  |57.096656|-2.258102|S99999999|NULL|S23000009|6253|S99999999|AB10AF    |true      |
# +-------+--------+-------+------+------+--------+--------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+-------+-----+---------+---------+---------+----+---------+----+---------+----------+----------+
# only showing top 5 rows
# [Stage 846:>                                                        (0 + 3) / 3]
# +---+----+----+------+------+--------+--------+--------+--------+----+---+---+----+----+-----+----+---+----+----+---+-----+------+------+----+-----+-----+-------+-----+---+----+----+----+---+---+---+----------+----------+
# |pcd|pcd2|pcds|dointr|doterm|usertype|oseast1m|osnrth1m|osgrdind|oa21|cty|ced|laua|ward|nhser|ctry|rgn|pcon|ttwa|itl|npark|lsoa21|msoa21|wz11|sicbl|bua22|ru11ind|oac11|lat|long|lep1|lep2|pfa|imd|icb|pcds_clean|valid_pcds|
# +---+----+----+------+------+--------+--------+--------+--------+----+---+---+----+----+-----+----+---+----+----+---+-----+------+------+----+-----+-----+-------+-----+---+----+----+----+---+---+---+----------+----------+
# +---+----+----+------+------+--------+--------+--------+--------+----+---+---+----+----+-----+----+---+----+----+---+-----+------+------+----+-----+-----+-------+-----+---+----+----+----+---+---+---+----------+----------+

# %% [markdown]
# #### Save the tables to the Silver

# %%
df_locations_cleaned.select("LocationId", "OrganisationID", "LocationPostCode_clean") \
.write.csv("Silver/locations_cleaned.csv", header=True, mode="overwrite")

df_lookup_full_CL_cleaned.select("pcds_clean", "ru11ind", "lat", "long") \
    .write.csv("Silver/lookup_full_cleaned.csv", header=True, mode="overwrite")
    
df_rural_lookup_full_CL_cleaned.select("pcds_clean", "ladnm") \
    .write.csv("Silver/rural_lookup_full_CL_cleaned.csv", header=True, mode="overwrite")

print("The tables have been saved to the Silver.")
# Out:
# [Stage 849:>                                                        (0 + 8) / 8]
# The tables have been saved to the Silver.

# %% [markdown]
# #### Check pcd, pcd2, and pcds columns whether they have same data or not

# %%
# from pyspark.sql.functions import col, regexp_replace

# # Remove spaces from all three columns
# df = df_lookup_full.withColumn("pcd_clean", regexp_replace(col("pcd"), "\\s+", ""))
# df = df.withColumn("pcd2_clean", regexp_replace(col("pcd2"), "\\s+", ""))
# df = df.withColumn("pcds_clean", regexp_replace(col("pcds"), "\\s+", ""))
# df_lookup_full_filtered = df
# df_lookup_full_filtered.show()

# # Now compare the cleaned columns
# unmatched_rows = df_lookup_full_filtered.filter(
#     (col("pcd_clean") != col("pcd2_clean")) | 
#     (col("pcd_clean") != col("pcds_clean")) | 
#     (col("pcd2_clean") != col("pcds_clean"))
# )

# print("Number of unmatched rows: ",unmatched_rows.count())
# unmatched_rows.show(5)

# %% [markdown]
# #### Option to filter null values for files where necessary

# %%
# # Locations file
# print("Total rows: ",df_locations.count())
# df_locations_filtered = df_locations.filter(df_locations.LocationPostCode.isNotNull())
# print("Number of rows which are not null on LocationPostCode column:",df_locations_filtered.count())

# # NSPL21_AUG_2023_UK file
# print("Total rows: ",df_lookup_full.count())
# df_lookup_full_filtered = df_lookup_full.filter(df_lookup_full.ru11ind.isNotNull())
# print("Number of rows which are not null on ru11ind column:",df_lookup_full_filtered.count())
# print("Difference in rows:", df_lookup_full.count() - df_lookup_full_filtered.count())

# # NSP21CL_AUG23_UK_LU file
# total_rows = df_rural_lookup_full_CL.count()
# print("Total rows:", total_rows)

# df_rural_lookup_full_CL_filtered = df_rural_lookup_full_CL \
#     .filter(df_rural_lookup_full_CL.ladnm.isNotNull())

# filtered_rows = df_rural_lookup_full_CL_filtered.count()
# print("Rows after removing nulls on ladnm columns:", filtered_rows)
# print("Difference in rows:", total_rows - filtered_rows)

# %% [markdown]
# #### Option to fill null values in 'ru11ind' column

# %%
# from pyspark.sql.functions import min, max

# # Group by 'ru11ind' and calculate min/max of 'lat' and 'long'
# agg_df = df_lookup_full.groupBy("ru11ind").agg(
#     min("lat").alias("min_lat"),
#     max("lat").alias("max_lat"),
#     min("long").alias("min_long"),
#     max("long").alias("max_long")
# ).orderBy("ru11ind")

# # Show the result
# agg_df.show()
